# %%
import sys
import os

sys.path.append(os.path.dirname(os.path.abspath('.')))

from core.chatbot import ChatBot

chatbot = ChatBot()
# Out:
# ✅ Connected to PostgreSQL: origin_insights@aurora-origin-pgsql.cluster-ccxs8qm4e2wy.us-east-1.rds.amazonaws.com:5432
# ✅ Connected to PostgreSQL: origin_insights@aurora-origin-pgsql.cluster-ccxs8qm4e2wy.us-east-1.rds.amazonaws.com:5432
# ✅ Connected to PostgreSQL: origin_insights@aurora-origin-pgsql.cluster-ccxs8qm4e2wy.us-east-1.rds.amazonaws.com:5432

# %% [markdown]
# ## Questions

# %% [markdown]
# ## Validacion de titulos

# %%
question = "¿Puedes validar el título 'The Matrix'?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758738601_6d6d5cb7
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.28s | {'messages': HumanMessage(content="¿Puedes validar el título 'The Matrix'?", additional_kwargs={}, response_metadata={}, id='018f3d08-441a-42bf-8405-6c6a1a5e2a9a')}
# ...

# %%
question = "peliculas de Sofia Coppola"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758233567_ae62a995
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.17s | {'messages': HumanMessage(content='peliculas de Sofia Coppola', additional_kwargs={}, response_metadata={}, id='f88a6516-bf5b-496d-bd6e-a491c8fa4325')}
# ...

# %%
question = "peliculas de Sofia Coppola"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758233576_6e543282
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='peliculas de Sofia Coppola', additional_kwargs={}, response_metadata={}, id='5b15c1b5-b057-4536-a9cc-eb9830989ad8')}
# ...

# %%
question = "¿Es válido el título 'Inception'?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758231792_f678c9ba
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.21s | {'messages': HumanMessage(content="¿Es válido el título 'Inception'?", additional_kwargs={}, response_metadata={}, id='56d1f288-a511-487e-bff4-58193d54e75f')}
# ...

# %%
question = "1"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758233596_7e942aa2
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='1', additional_kwargs={}, response_metadata={}, id='d0e9200d-24bf-4924-8a11-4b6d69478c30')}
# ...

# %%
question = "1"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758233652_7c8e8c38
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='1', additional_kwargs={}, response_metadata={}, id='9a775b29-acd6-4dd2-8125-c23ef79ecd35')}
# ...

# %%
question = "informacion de 'Star Wars' "
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758233681_d5fdb5ff
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content="informacion de 'Star Wars' ", additional_kwargs={}, response_metadata={}, id='eef93948-8e02-4224-91c7-3bd741792c74')}
# ...

# %%
question = "7"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758234140_4148968f
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='7', additional_kwargs={}, response_metadata={}, id='0567ae23-bcff-45f8-b069-c001bdcf2710')}
# ...

# %%
question = "que informacion hay sobre ese uid?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758234189_1847cc8c
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.17s | {'messages': HumanMessage(content='que informacion hay sobre ese uid?', additional_kwargs={}, response_metadata={}, id='a9d3fdc8-9107-4b57-912b-17cfe6921d73')}
# ...

# %%
question = "cual es el rating de avengers en US?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758287531_0702d313
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.17s | {'messages': HumanMessage(content='cual es el rating de avengers en US?', additional_kwargs={}, response_metadata={}, id='80c658f5-61ac-4a4d-97f1-776de28c7233')}
# ...

# %% [markdown]
# ## Cast & Directors

# %%
question = "¿Con qué actores trabajó Meryl Streep?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758290130_92687c52
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.25s | {'messages': HumanMessage(content='¿Con qué actores trabajó Meryl Streep?', additional_kwargs={}, response_metadata={}, id='de2a3146-2404-4488-bc0f-1525638e78f0')}
# ...

# %%
question = "¿Qué proyectos tienen en común Brad Pitt y David Fincher?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758294085_2dc798f4
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.27s | {'messages': HumanMessage(content='¿Qué proyectos tienen en común Brad Pitt y David Fincher?', additional_kwargs={}, response_metadata={}, id='8d5f913a-19ff-4bdf-b293-5b7f5d2d6c43')}
# ...

# %%
question = "¿Qué pasa si busco John Smith"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué pasa si busco John Smith', additional_kwargs={}, response_metadata={}, id='2057e9c1-8700-4665-96ce-44760e4e1eaa')}
# ...

# %%
question = "¿Puedes encontrar a Scarlett Johansson?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Puedes encontrar a Scarlett Johansson?', additional_kwargs={}, response_metadata={}, id='1feefcbb-37b3-4abf-b811-7ada91a648da')}
# ...

# %%
question = "¿Existe el actor Robert Downey Jr?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758295829_612829d2
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.32s | {'messages': HumanMessage(content='¿Existe el actor Robert Downey Jr?', additional_kwargs={}, response_metadata={}, id='2fcb7b1e-b435-4aed-8bbc-6b47e8503dd3')}
# ...

# %%
question = "¿Puedes validar al director Christopher Nolan?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758295874_555cf6c7
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='¿Puedes validar al director Christopher Nolan?', additional_kwargs={}, response_metadata={}, id='f2936f11-3aaa-472c-beaf-01651aa6b707')}
# ...

# %%
question = "¿Existe Steven Spielberg en la base de datos?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Existe Steven Spielberg en la base de datos?', additional_kwargs={}, response_metadata={}, id='7213f0b9-053d-4a06-864b-e1a03bf69f48')}
# ...

# %%
question = "¿Qué pasa si busco John Smith como director?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Qué pasa si busco John Smith como director?', additional_kwargs={}, response_metadata={}, id='785a9f0c-787b-450c-a731-6e1ebc8c9a22')}
# ...

# %%
question = "¿Puedes encontrar a Martin Scorsese?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Puedes encontrar a Martin Scorsese?', additional_kwargs={}, response_metadata={}, id='b27f8639-eed8-4124-bec7-7e0bb644b722')}
# ...

# %%
question = "¿Está Quentin Tarantino registrado?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Está Quentin Tarantino registrado?', additional_kwargs={}, response_metadata={}, id='c72d0517-d2fa-4534-927f-cc8b5b5e7318')}
# ...

# %%
question = "informacion de 1"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='informacion de 1', additional_kwargs={}, response_metadata={}, id='a5d5ff75-f325-4709-8db7-ae08dad96a89')}
# ...

# %% [markdown]
# ## CONTENT INFORMATION TOOLS

# %%
question = "¿Cuál es la filmografía completa de 028160bd84839a6e3350db69a546d62f?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758295887_2c3b268f
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='¿Cuál es la filmografía completa de 028160bd84839a6e3350db69a546d62f?', additional_kwargs={}, response_metadata={}, id='8b79ec9b-4b1b-4f5a-b24a-dd3d97fc40fc')}
# ...

# %%
question = "¿Qué rating tiene e4586df7245e62f7aae68a652c4539b5?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758295894_12d421c5
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.16s | {'messages': HumanMessage(content='¿Qué rating tiene e4586df7245e62f7aae68a652c4539b5?', additional_kwargs={}, response_metadata={}, id='6f18f324-8437-41d0-9550-b7934affdbba')}
# ...

# %%
question = "top de netflix en 2024"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='top de netflix en 2024', additional_kwargs={}, response_metadata={}, id='f5d8aafe-9bc7-4bc7-acb4-fd612184b5bf')}
# ...

# %%
question = "top de peliculas de terror"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='top de peliculas de terror', additional_kwargs={}, response_metadata={}, id='3d9d5d66-1cb6-445e-8517-0a2dd05f8306')}
# ...

# %%
question = "Series de ciencia ficción con mejor puntuación"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='Series de ciencia ficción con mejor puntuación', additional_kwargs={}, response_metadata={}, id='88107098-500b-46c6-acfc-dd63cae81456')}
# ...

# %%
question = "Directores más populares en 2023"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='Directores más populares en 2023', additional_kwargs={}, response_metadata={}, id='765c3dec-40eb-41af-9bb6-ed1955f8439c')}
# ...

# %%
uestion = "¿Cuál fue el rating de Avengers Endgame?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='Directores más populares en 2023', additional_kwargs={}, response_metadata={}, id='04155ca2-b7fc-41cc-a7c6-987efd4e2541')}
# ...

# %%
question = "¿Cuál es la puntuación de The Matrix?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Cuál es la puntuación de The Matrix?', additional_kwargs={}, response_metadata={}, id='d15c43e6-04c8-4cd3-8f42-f6cfcbd86ae5')}
# ...

# %% [markdown]
# ## ACTOR ANALYSIS TOOLS

# %%
question = "¿Cuál es la filmografía completa de Leonardo DiCaprio?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Cuál es la filmografía completa de Leonardo DiCaprio?', additional_kwargs={}, response_metadata={}, id='a8cbc6fa-470c-4d32-8ead-381a611403e8')}
# ...

# %%
question = "¿Puedes mostrarme todos los co-actores de Scarlett Johansson?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Puedes mostrarme todos los co-actores de Scarlett Johansson?', additional_kwargs={}, response_metadata={}, id='8fdb982c-91dc-4f09-a757-2f4ca0ec1a8a')}
# ...

# %%
question = "¿En qué películas ha aparecido Robert Downey Jr.?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿En qué películas ha aparecido Robert Downey Jr.?', additional_kwargs={}, response_metadata={}, id='1f2cd166-6846-4c98-890b-7576068965d6')}
# ...

# %%
question = "¿Cuáles son las colaboraciones más frecuentes de Will Smith?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Cuáles son las colaboraciones más frecuentes de Will Smith?', additional_kwargs={}, response_metadata={}, id='d1b3ac1f-965b-40e0-a172-77b0f8f6257e')}
# ...

# %%
question = "¿Con qué actrices ha trabajado más Brad Pitt?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Con qué actrices ha trabajado más Brad Pitt?', additional_kwargs={}, response_metadata={}, id='ffaa0a46-c415-4be7-a5c0-0a97da8ce0b2')}
# ...

# %%
question = "¿Qué actores aparecen frecuentemente con Jennifer Lawrence?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué actores aparecen frecuentemente con Jennifer Lawrence?', additional_kwargs={}, response_metadata={}, id='b35a4366-1b0f-4e21-806c-0b2da6d85427')}
# ...

# %% [markdown]
# ## Directors

# %%
question = "¿Cuál es la filmografía completa de Christopher Nolan?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Cuál es la filmografía completa de Christopher Nolan?', additional_kwargs={}, response_metadata={}, id='7bf63980-df40-4b3b-80e8-ea8d68d3cc89')}
# ...

# %%
question = "¿Con qué directores ha colaborado Steven Spielberg?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Con qué directores ha colaborado Steven Spielberg?', additional_kwargs={}, response_metadata={}, id='f7c74247-97c0-4362-87d8-c464ccfb808a')}
# ...

# %%
question = "¿Qué películas ha dirigido Martin Scorsese?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué películas ha dirigido Martin Scorsese?', additional_kwargs={}, response_metadata={}, id='9cd7cb70-11a4-40ec-b357-bb4dc4512ae9')}
# ...

# %%
question = "¿Cuáles son los co-directores más frecuentes de los hermanos Russo?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Cuáles son los co-directores más frecuentes de los hermanos Russo?', additional_kwargs={}, response_metadata={}, id='59236616-e823-4e97-8956-b89cb1fa7e42')}
# ...

# %%
question = "¿En qué proyectos han trabajado juntos Leonardo DiCaprio y Christopher Nolan?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿En qué proyectos han trabajado juntos Leonardo DiCaprio y Christopher Nolan?', additional_kwargs={}, response_metadata={}, id='38f0d83f-07c9-448f-be81-244b831f8b6d')}
# ...

# %%
question = "¿Qué colaboraciones existen entre Tom Hanks y Steven Spielberg?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué colaboraciones existen entre Tom Hanks y Steven Spielberg?', additional_kwargs={}, response_metadata={}, id='6169090d-ab5b-4a28-a40c-2de359039849')}
# ...

# %% [markdown]
# ##  PLATFORM & AVAILABILITY TOOLS

# %%
question = "¿En qué plataformas está disponible The Matrix en Estados Unidos?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿En qué plataformas está disponible The Matrix en Estados Unidos?', additional_kwargs={}, response_metadata={}, id='121c2c94-174d-45e6-98fb-f888f05661f7')}
# ...

# %%
question = "¿Dónde puedo ver Inception en España?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Dónde puedo ver Inception en España?', additional_kwargs={}, response_metadata={}, id='303a4483-c124-4eac-af8c-f8328c87014e')}
# ...

# %%
question = "¿Qué plataformas tienen Avatar en Argentina?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Qué plataformas tienen Avatar en Argentina?', additional_kwargs={}, response_metadata={}, id='8f1f0f04-8115-49a8-a993-06512b0080ce')}
# ...

# %%
question = "¿Está Titanic disponible en Netflix en Japón?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Está Titanic disponible en Netflix en Japón?', additional_kwargs={}, response_metadata={}, id='5c034531-d1ee-481b-936e-08384c528d8f')}
# ...

# %% [markdown]
# ## Exclusivos por Plataforma

# %%
question = "¿Qué actores tienen más contenido en Netflix Estados Unidos?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Qué actores tienen más contenido en Netflix Estados Unidos?', additional_kwargs={}, response_metadata={}, id='21e6f951-583c-4a5f-a9e2-2e8bd3804c21')}
# ...

# %%
question = "¿Cuáles son las preferencias de actores de Amazon Prime en España?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.03s | {'messages': HumanMessage(content='¿Cuáles son las preferencias de actores de Amazon Prime en España?', additional_kwargs={}, response_metadata={}, id='1b3106e9-1358-49e7-b9da-8600a6ca94c5')}
# ...

# %%
question = "¿Qué estrellas aparecen más en Disney+ globalmente?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Qué estrellas aparecen más en Disney+ globalmente?', additional_kwargs={}, response_metadata={}, id='7429cf09-878a-4c79-a57e-ce0504d782c3')}
# ...

# %%
question = "¿Qué directores tienen más películas en Netflix?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué directores tienen más películas en Netflix?', additional_kwargs={}, response_metadata={}, id='898774ad-eafe-4a59-a410-c79408d1a0f6')}
# ...

# %%
question = "¿Cuál es la distribución de Christopher Nolan entre plataformas?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿Cuál es la distribución de Christopher Nolan entre plataformas?', additional_kwargs={}, response_metadata={}, id='1a12c1cd-46fd-4d38-ba8c-212a979a9ac1')}
# ...

# %%
question = "¿En qué plataformas está más presente Steven Spielberg?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='¿En qué plataformas está más presente Steven Spielberg?', additional_kwargs={}, response_metadata={}, id='508bc3a8-9439-43f5-9c46-f1b72f1a2988')}
# ...

# %%
question = "¿Qué tan similar es el catálogo de Netflix entre Estados Unidos y España?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué tan similar es el catálogo de Netflix entre Estados Unidos y España?', additional_kwargs={}, response_metadata={}, id='524d74e0-c497-4637-929d-ce7a9aa7963e')}
# ...

# %%
question = "¿Cuál es la diferencia entre Amazon Prime US y UK?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='¿Cuál es la diferencia entre Amazon Prime US y UK?', additional_kwargs={}, response_metadata={}, id='cb2dcb87-4ab1-4b30-9015-756a24ebdfcd')}
# ...

# %%
question = "¿Qué contenido está en Netflix US pero no en Netflix México?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué contenido está en Netflix US pero no en Netflix México?', additional_kwargs={}, response_metadata={}, id='6a0791a2-90bc-416d-a736-02e26ab514f4')}
# ...

# %%
question = "¿Qué plataformas tienen más exclusivos en Asia?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿Qué plataformas tienen más exclusivos en Asia?', additional_kwargs={}, response_metadata={}, id='59f916ca-5d83-4394-b911-81af2f007806')}
# ...

# %%
question = "¿Cuál es el ranking de exclusivos en Europa?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.03s | {'messages': HumanMessage(content='¿Cuál es el ranking de exclusivos en Europa?', additional_kwargs={}, response_metadata={}, id='defd2bcb-2f09-48a4-9f91-77d66cc89076')}
# ...

# %%
question = "¿Qué plataforma domina en América Latina?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.03s | {'messages': HumanMessage(content='¿Qué plataforma domina en América Latina?', additional_kwargs={}, response_metadata={}, id='d2a8d522-d340-4a38-a9c3-90012601bfc0')}
# ...

# %%
question = "¿Qué títulos están en Netflix US pero no en Netflix España?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.06s | {'messages': HumanMessage(content='¿Qué títulos están en Netflix US pero no en Netflix España?', additional_kwargs={}, response_metadata={}, id='ed381c80-53ee-429f-a468-5eeb992c0d51')}
# ...

# %% [markdown]
# ## Quality

# %%
question = "¿En qué calidades está disponible The Matrix en Estados Unidos?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='¿En qué calidades está disponible The Matrix en Estados Unidos?', additional_kwargs={}, response_metadata={}, id='474cb5e5-88a6-4e91-9e9b-069846149001')}
# ...

# %%
question = "Cuánto cuesta rentar Avatar en Estados Unidos?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='Cuánto cuesta rentar Avatar en Estados Unidos?', additional_kwargs={}, response_metadata={}, id='114ba708-7cc6-4c06-8942-3a6c1d4fe1ed')}
# ...

# %%
question =" cuantos tipos de generos de data hay¿"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758307951_335a18a1
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.24s | {'messages': HumanMessage(content=' cuantos tipos de generos de data hay¿', additional_kwargs={}, response_metadata={}, id='7c6080ed-f657-4978-8f84-1fe4335b5eda')}
# ...

# %%
question =" ¿Cuántas series hay en US?"
answer = chatbot.answer_question(question)

# %%
question ="Dame estadísticas generales"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758308132_fcaf694a
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.2s | {'messages': HumanMessage(content='Dame estadísticas generales', additional_kwargs={}, response_metadata={}, id='1f319448-f9ee-4aef-ac4c-4d32504fdf26')}
# ...

# %%
question =" ¿Cuántas series hay en US?"
answer = chatbot.answer_question(question)

# %%
question =" ¿Cuántas series hay en US?"
answer = chatbot.answer_question(question)
# Out:
# 🆕 Nuevo thread creado: session_chat_1758308083_2fbddd43
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.27s | {'messages': HumanMessage(content=' ¿Cuántas series hay en US?', additional_kwargs={}, response_metadata={}, id='fda2d3f8-3793-46c7-a020-9917ab9929c5')}
# ...

# %% [markdown]
# ## Ratings y top

# %%
question = "¿Cuáles son los top 10 en Netflix Estados Unidos?"
answer = chatbot.answer_question(question)
9
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='¿Cuáles son los top 10 en Netflix Estados Unidos?', additional_kwargs={}, response_metadata={}, id='cb8657c3-a021-4801-aa17-80f24ae76b65')}
# ...

# %%
question = "¿Qué exclusivos tiene que Amazon Prime no tenga?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='¿Qué exclusivos tiene que Amazon Prime no tenga?', additional_kwargs={}, response_metadata={}, id='f29f652c-2cfd-481d-80f3-97742727e883')}
# ...

# %%
question = "¿Qué plataformas están disponibles en AR?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='¿Qué plataformas están disponibles en AR?', additional_kwargs={}, response_metadata={}, id='c54b2f69-674c-4635-845f-f20d2c19d151')}
# ...

# %%
question = "¿Cuántos títulos hay en new_cp_presence para Argentina?"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='¿Cuántos títulos hay en new_cp_presence para Argentina?', additional_kwargs={}, response_metadata={}, id='29d5f85f-78d8-47d9-9bd3-6a1648c1dcae')}
# ...

# %%
question = "Listame los planes disponibles en new_cp_presence en México."
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='Listame los planes disponibles en new_cp_presence en México.', additional_kwargs={}, response_metadata={}, id='4613a29e-2816-444c-854c-00641d428a78')}
# ...

# %%
question = "Estadísticas de new_cp_presence filtrando por tipo movie."
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content='Estadísticas de new_cp_presence filtrando por tipo movie.', additional_kwargs={}, response_metadata={}, id='80fc2e18-bd63-4338-a6d3-1d63043a0e31')}
# ...

# %%
question = "Estadísticas de new_cp_presence filtrando por tipo movies"
answer = chatbot.answer_question(question)
# Out:
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.05s | {'messages': HumanMessage(content='Estadísticas de new_cp_presence filtrando por tipo movies', additional_kwargs={}, response_metadata={}, id='d2af9727-ff70-4768-bd46-49271b99fb5c')}
# Error raised by bedrock service
# Traceback (most recent call last):
#   File "c:\Users\ELEANA RINAUDO\Documents\chatbot\.env\Lib\site-packages\langchain_aws\llms\bedrock.py", line 979, in _prepare_input_and_invoke
#     response = self.client.invoke_model(**request_options)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ELEANA RINAUDO\Documents\chatbot\.env\Lib\site-packages\botocore\client.py", line 602, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\ELEANA RINAUDO\Documents\chatbot\.env\Lib\site-packages\botocore\context.py", line 123, in wrapper
#     return func(*args, **kwargs)
# ...

# %% [markdown]
# ## Title

# %%
question = "Busca información sobre 'Stranger Things"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content="Busca información sobre 'Stranger Things", additional_kwargs={}, response_metadata={}, id='dc2b1925-34df-48f6-b7d4-0782589d41dd')}
# INFO:src.tools.sql.akas:Validating title: 'Stranger Things'
# ...

# %%
question = "1"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='1', additional_kwargs={}, response_metadata={}, id='10309113-c24e-4c78-b000-fd9a4592e481')}
# ...

# %%
question = "¿Qué sabes de 'The Matrix'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content="¿Qué sabes de 'The Matrix'?", additional_kwargs={}, response_metadata={}, id='bf7f83c6-dfe5-445c-9d91-1b8e2fb9fd55')}
# INFO:src.tools.sql.akas:Validating title: 'The Matrix'
# ...

# %%
question = "¿Qué sabes de 'The Matrix'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="¿Qué sabes de 'The Matrix'?", additional_kwargs={}, response_metadata={}, id='a5accdee-b2f4-49ea-99b0-619228caafff')}
# INFO:src.tools.sql.akas:Validating title: 'The Matrix'
# ...

# %%
question = "Valida el título 'Pulp Fiction'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content="Valida el título 'Pulp Fiction'", additional_kwargs={}, response_metadata={}, id='2e25dd4d-0f2c-464b-936b-a45f10a5b373')}
# INFO:src.tools.sql.akas:Validating title: 'Pulp Fiction'
# ...

# %%
question = "Busco datos de 'Avatar'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content="Busco datos de 'Avatar'", additional_kwargs={}, response_metadata={}, id='c13d4800-15c8-4650-8ca1-569ca4e3618d')}
# INFO:src.tools.sql.akas:Validating title: 'Avatar'
# ...

# %%
question = "2"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='2', additional_kwargs={}, response_metadata={}, id='ec253ca5-1ff0-4822-935e-77f0068d1da0')}
# ...

# %%
question = "Información sobre 'xyz123invalid'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.02s | {'messages': HumanMessage(content="Información sobre 'xyz123invalid'", additional_kwargs={}, response_metadata={}, id='cd0d4b47-8fe9-4b86-a3d5-33a9eaa2b038')}
# INFO:src.tools.sql.akas:Validating title: 'xyz123invalid'
# ...

# %% [markdown]
# ## validate_actors

# %%
question = "Busca al actor 'Leonardo DiCaprio'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Busca al actor 'Leonardo DiCaprio'", additional_kwargs={}, response_metadata={}, id='9b642bfa-a259-4359-a5ee-98e9c4261d6a')}
# ...

# %%
question = "¿Conoces a 'Robert Downey Jr'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="¿Conoces a 'Robert Downey Jr'?", additional_kwargs={}, response_metadata={}, id='6473159b-9803-4965-81f2-4987ed905c9d')}
# ...

# %%
question = "¿Conoces a 'Robert Downey Jr'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content="¿Conoces a 'Robert Downey Jr'?", additional_kwargs={}, response_metadata={}, id='003d34fd-e28f-4263-8d68-24220afcb6f4')}
# ...

# %%
question = "Busco información de 'Will Smith'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Busco información de 'Will Smith'", additional_kwargs={}, response_metadata={}, id='d5c1a62f-772e-4497-a9d4-92844e83cea1')}
# ...

# %%
question = "¿Existe el actor 'ActorInexistente123'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content="¿Existe el actor 'ActorInexistente123'?", additional_kwargs={}, response_metadata={}, id='771c0df2-324e-4a19-8685-00dabe06ac2b')}
# ...

# %%
question = "Busca al director 'Christopher Nolan'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Busca al director 'Christopher Nolan'", additional_kwargs={}, response_metadata={}, id='ce03d48d-b52f-47e8-b829-8a6d99954b46')}
# ...

# %%
question = "¿Conoces a 'Spielberg'?"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="¿Conoces a 'Spielberg'?", additional_kwargs={}, response_metadata={}, id='3b832386-8626-4eca-bfdf-aef08c090571')}
# ...

# %%
question = "Valida 'Steven Spielberg'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Valida 'Steven Spielberg'", additional_kwargs={}, response_metadata={}, id='0cdf2420-5004-4ba7-8cce-55fddf3d6a28')}
# ...

# %%
question = "Busco a 'Tarantino'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Busco a 'Tarantino'", additional_kwargs={}, response_metadata={}, id='825b158b-e486-438c-9742-996179413e6d')}
# ...

# %%
question = "Muestra la filmografía de 'Johnson'"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content="Muestra la filmografía de 'Johnson'", additional_kwargs={}, response_metadata={}, id='090100a3-224d-4d50-a1fd-3eaaa7ae512b')}
# ...

# %%
question = "top de series mas populares en chile en 2023"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:  0.01s | {'messages': HumanMessage(content='top de series mas populares en chile en 2023', additional_kwargs={}, response_metadata={}, id='e8777e00-b5c3-462e-b707-00560498fbf9')}
# INFO:src.tools.sql.db_utils_sql:✅ platform_name_iso consultados, total: 240
# ...

# %%
question = "top de series mas populares en chile en 2024"
answer = chatbot.answer_question(question)
# Out:
# INFO:langchain_aws.llms.bedrock:Using Bedrock Invoke API to generate response
# ENTRA A GET EVENTS LAST MESSAGE
# (LangGraph       ) Time:   0.0s | {'messages': HumanMessage(content='top de series mas populares en chile en 2024', additional_kwargs={}, response_metadata={}, id='7a35eadd-323d-4d68-857e-f44f3fb69064')}
# INFO:src.tools.sql.db_utils_sql:✅ platform_name_iso consultados, total: 240
# ...
