# %% [markdown]
# # 🧪 Test de Flujo Completo de Grafos
#
# Este notebook valida el flujo end-to-end de todos los grafos del sistema:
#
# ## Grafos a Probar:
# 1. **TALENT** - Actores, Directores, Colaboraciones
# 2. **CONTENT** - Metadata, Discovery
# 3. **PLATFORM** - Availability, Presence
# 4. **BUSINESS** - Pricing, Rankings, Intelligence
# 5. **COMMON** - Validation, Admin
#
# ## Flujo de Cada Test:
# ```
# Pregunta del Usuario
#     ↓
# Main Router → Selecciona Grafo
#     ↓
# Validation Preprocessor → Valida entidades (si es necesario)
#     ↓
# Sub-Grafo → Procesa pregunta
#     ↓
# Classifier → Selecciona nodo
#     ↓
# Router → Selecciona tool
#     ↓
# Agent → Ejecuta tool y genera respuesta
#     ↓
# Supervisor → Decide si continuar o terminar
#     ↓
# Formatter → Formatea respuesta final
# ```

# %%
# Setup
import sys
import asyncio
import json
from pprint import pprint

# Import main router
from src.strands.main_router.graph import process_question_main

print("✅ Imports completados")
# Out:
# Loading validation data from platform_name_iso
# ✅ Imports completados

# %% [markdown]
# ## Helper Functions

# %%
async def test_question(question: str):
    """
    Prueba una pregunta y valida el flujo completo.
    """
    print("\n" + "="*80)
    print("="*80)
    print(f"❓ Pregunta: {question}")
    print("="*80 + "\n")
    
    try:
        result = await process_question_main(question)
        
        print("\n" + "="*80)
        print("📊 RESULTADO")
        print("="*80)
        
        # Verificar si necesita desambiguación
        if result.get('needs_user_input'):
            print("⚠️  DESAMBIGUACIÓN REQUERIDA")
            print(f"📝 Mensaje: {result.get('validation_message', 'N/A')[:300]}...")
            return {
                "status": "disambiguation",
                "question": question,
                "message": result.get('validation_message')
            }
        
        # Verificar respuesta
        answer = result.get('answer', 'N/A')
        print(f"✅ Respuesta: {answer[:400]}...")
        
        # Metadata
        print(f"\n📋 Metadata:")
        print(f"   • Grafo usado: {result.get('graph_used', 'N/A')}")
        print(f"   • Validación realizada: {result.get('validation_done', False)}")
        print(f"   • Tool calls: {result.get('tool_calls_count', 0)}")
        print(f"   • Re-routings: {result.get('re_routing_count', 0)}")
        
        print("="*80 + "\n")
        
        return {
            "status": "success",
            "question": question,
            "answer": answer[:200]
        }
        
    except Exception as e:
        print(f"\n❌ ERROR: {e}\n")
        import traceback
        traceback.print_exc()
        return {
            "status": "error",
            "question": question,
            "error": str(e)
        }

# %% [markdown]
# ## 1. TALENT Graph Tests
#
# ### Flujo esperado:
# ```
# Main Router → TALENT
#     ↓
# Validation → validate_director/validate_actor
#     ↓
# Talent Classifier → directors/actors/collaborations
#     ↓
# Router → Selecciona tool específica
#     ↓
# Agent → Ejecuta y responde
# ```

# %% [markdown]
# ## validado

# %%
# Test 1.1: Director Filmography
result_1_1 = await test_question(
    question="¿Qué películas ha dirigido Christopher Nolan?"
)
# Out:
# ================================================================================
# ================================================================================
# ❓ Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# ================================================================================
#
# ⚠️  Creando grafo con flujo SECUENCIAL (legacy)
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# [VALIDATION] 🤖 Ejecutando validación con LLM...
# Para comenzar, validaré el nombre del director:
# Tool #1: validate_director
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director exact search
# 📄 Query:
#
# WITH q AS (SELECT %s::text AS s)
# SELECT
#   d.id,
#   d.name,
#   t.n_titles
# FROM ms.directors d
# CROSS JOIN q
# LEFT JOIN LATERAL (
#   SELECT COUNT(*)::integer AS n_titles
#   FROM ms.directed_by db
#   WHERE db.director_id = d.id
# ) t ON TRUE
# WHERE d.name ILIKE q.s
# ORDER BY t.n_titles DESC NULLS LAST, d.name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Christopher Nolan',)
# ================================================================================
#
# ✅ Query retornó 1 filas en 1.418s
#
# Christopher Nolan validado (ID: 615683)
#
# Sin embargo, para listar sus películas necesitaría una herramienta adicional que no está disponible en mi conjunto actual de funciones. Solo puedo validar la existencia del director, pero no puedo recuperar su filmografía con las herramientas proporcionadas.
#
# Si deseas conocer sus películas, te sugiero consultar fuentes como IMDb, bases de datos de cine o la página web oficial del director.[VALIDATION] 📦 Resultado de validación:
#    {'role': 'assistant', 'content': [{'text': 'Christopher Nolan validado (ID: 615683)\n\nSin embargo, para listar sus películas necesitaría una herramienta adicional que no está disponible en mi conjunto actual de funciones. Solo puedo validar la existencia del director, pero no puedo recuperar su fil...
# [VALIDATION] ✅ Validación completada
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha dirigido Christopher Nolan?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.58s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Para responder esta pregunta, necesito usar la herramienta de obtener filmografía del director. Sin embargo, note que necesito usar el ID numérico del director, no su nombre.
#
# Asumiré que ya hay un ID validado para Christopher Nolan, pero en este caso no lo veo proporcionado. Sin el ID numérico específico, no puedo realizar la consulta directamente.
#
# Lo más recomendable sería que me proporcione el ID numérico de Christopher Nolan para poder obtener su filmografía completa. El ID numérico es diferente del ID de IMDB y es necesario para usar la herramienta de manera precisa.
#
# ¿Podría proporcionarme el ID numérico de Christopher Nolan para buscar sus películas?[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Para responder esta pregunta, necesito usar la herramienta de obtener filmografía del director. Sin embargo, note que necesito usar el ID numérico del director, no su nombre.\n\nAsumiré que ya hay un ID validado para Christopher Nolan, pero en este caso no lo veo proporcionado. Sin el ID numérico específico, no puedo realizar la consulta directamente.\n\nLo más recomendable sería que me proporcione el ID numérico de Christopher Nolan para poder obtener su filmografía completa. El ID numérico es diferente del ID de IMDB y es necesario para usar la herramienta de manera precisa.\n\n¿Podría proporcionarme el ID numérico de Christopher Nolan para buscar sus películas?'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 780 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# ⚠️ Talent graph no completó, volviendo al main router...
# 🔄 Re-routing #1 al main_router...
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# 🔄 REROUTING #1 desde talent_graph
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha dirigido Christopher Nolan?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.21s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Para obtener la filmografía de Christopher Nolan, necesito usar el ID numérico del director. Asumiré que ya ha sido validado previamente.
# Tool #1: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_2845
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (2845, 20)
# ================================================================================
#
# ✅ Query retornó 2 filas en 0.344s
#
# Disculpe, parece que ha habido un error con los resultados. Intentaré de nuevo con un límite menor:
# Tool #2: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_615683
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (615683, 10)
# ================================================================================
#
# ✅ Query retornó 10 filas en 0.296s
#
# Aquí están las películas que ha dirigido Christopher Nolan según los resultados más recientes:
#
# 1. Untitled Christopher Nolan Film (2026, próximamente)
# 2. Oppenheimer (2023)
# 3. Tenet (2020)
# 4. Dunkirk (2017)
# 5. Quay (2015)
# 6. Interstellar (2014)
# 7. The Dark Knight Rises (2012)
# 8. Inception (2010)
#
# Nota: La lista muestra sus 10 trabajos más recientes. Christopher Nolan ha dirigido más películas que no aparecen aquí, como la trilogía de Batman (Batman Begins, The Dark Knight) y otras como Memento, El Prestigio, etc. La herramienta muestra los 10 trabajos más recientes por defecto.
#
# Su película más reciente es Oppenheimer (2023), y tiene un proyecto sin título programado para 2026.[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Aquí están las películas que ha dirigido Christopher Nolan según los resultados más recientes:\n\n1. Untitled Christopher Nolan Film (2026, próximamente)\n2. Oppenheimer (2023)\n3. Tenet (2020)\n4. Dunkirk (2017)\n5. Quay (2015)\n6. Interstellar (2014)\n7. The Dark Knight Rises (2012)\n8. Inception (2010)\n\nNota: La lista muestra sus 10 trabajos más recientes. Christopher Nolan ha dirigido más películas que no aparecen aquí, como la trilogía de Batman (Batman Begins, The Dark Knight) y otras como Memento, El Prestigio, etc. La herramienta muestra los 10 trabajos más recientes por defecto.\n\nSu película más reciente es Oppenheimer (2023), y tiene un proyecto sin título programado para 2026.'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 808 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# ⚠️ Talent graph no completó, volviendo al main router...
# 🔄 Re-routing #2 al main_router...
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# 🔄 REROUTING #2 desde talent_graph
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha dirigido Christopher Nolan?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.04s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Para responder a esta pregunta, necesitaré usar el ID numérico de Christopher Nolan. Llamaré a la función para obtener su filmografía.
# Tool #1: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_524
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (524, 10)
# ================================================================================
#
# ✅ Query retornó 0 filas en 0.298s
#
# Me disculpo, parece que hubo un problema con el ID. Intentaré de nuevo con otro ID numérico.
# Tool #2: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_615683
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (615683, 10)
# ================================================================================
#
# ✅ Query retornó 10 filas en 0.300s
#
# Basándome en los resultados, aquí están las películas que ha dirigido Christopher Nolan:
#
# 1. Oppenheimer (2023)
# 2. Tenet (2020)
# 3. Dunkirk (2017)
# 4. Interstellar (2014)
# 5. The Dark Knight Rises (2012)
# 6. Inception (2010)
# 7. Quay (2015, cortometraje)
#
# También aparece un proyecto sin título para 2026 y una referencia a "Barbenheimer" en 2023.
#
# Es importante notar que esta lista muestra los 10 trabajos más recientes, por lo que podría no incluir todas sus películas anteriores como Batman Begins o Memento. La lista incluye tanto películas como series, aunque Nolan es principalmente conocido por sus películas de cine.[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Basándome en los resultados, aquí están las películas que ha dirigido Christopher Nolan:\n\n1. Oppenheimer (2023)\n2. Tenet (2020)\n3. Dunkirk (2017)\n4. Interstellar (2014)\n5. The Dark Knight Rises (2012)\n6. Inception (2010)\n7. Quay (2015, cortometraje)\n\nTambién aparece un proyecto sin título para 2026 y una referencia a "Barbenheimer" en 2023.\n\nEs importante notar que esta lista muestra los 10 trabajos más recientes, por lo que podría no incluir todas sus películas anteriores como Batman Begins o Memento. La lista incluye tanto películas como series, aunque Nolan es principalmente conocido por sus películas de cine.'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 740 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# COMPLETO[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'COMPLETO'}]}
# [SUPERVISOR] ✓ Pregunta respondida, ir a format
# Oppenheimer (2023)
# Tenet (2020)
# Dunkirk (2017)
# Interstellar (2014)
# The Dark Knight Rises (2012)
# Inception (2010)
# Quay (2015, cortometraje)
# ================================================================================
# 📊 RESULTADO
# ================================================================================
# ✅ Respuesta: {'role': 'assistant', 'content': [{'text': 'Oppenheimer (2023)\nTenet (2020)\nDunkirk (2017)\nInterstellar (2014)\nThe Dark Knight Rises (2012)\nInception (2010)\nQuay (2015, cortometraje)'}]}...
#
# 📋 Metadata:
#    • Grafo usado: N/A
#    • Validación realizada: True
#    • Tool calls: 0
#    • Re-routings: 0
# ================================================================================

# %% [markdown]
# ## no validado

# %%
# Test 1.2: Director Collaborators
result_1_2 = await test_question(
    question="¿Con quién ha colaborado Steven Spielberg?",
)
# Out:
# ================================================================================
# ================================================================================
# ❓ Pregunta: ¿Con quién ha colaborado Steven Spielberg?
# ================================================================================
#
# ⚠️  Creando grafo con flujo SECUENCIAL (legacy)
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿Con quién ha colaborado Steven Spielberg?
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: ¿Con quién ha colaborado Steven Spielberg?
# [VALIDATION] 🤖 Ejecutando validación con LLM...
# NO_VALIDATION_NEEDED
#
# Entiendo que quieres información sobre las colaboraciones de Steven Spielberg, pero la herramienta que tengo disponible solo permite validar su nombre como director. Primero, validaré su nombre:
# Tool #1: validate_director
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director exact search
# 📄 Query:
#
# WITH q AS (SELECT %s::text AS s)
# SELECT
#   d.id,
#   d.name,
#   t.n_titles
# FROM ms.directors d
# CROSS JOIN q
# LEFT JOIN LATERAL (
#   SELECT COUNT(*)::integer AS n_titles
#   FROM ms.directed_by db
#   WHERE db.director_id = d.id
# ) t ON TRUE
# WHERE d.name ILIKE q.s
# ORDER BY t.n_titles DESC NULLS LAST, d.name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Steven Spielberg',)
# ================================================================================
#
# ✅ Query retornó 1 filas en 1.407s
#
# Steven Spielberg validado (ID: 154395)
#
# Para obtener información detallada sobre sus colaboraciones, necesitarías consultar una base de datos o herramienta especializada que no está disponible en este sistema de validación.[VALIDATION] 📦 Resultado de validación:
#    {'role': 'assistant', 'content': [{'text': 'Steven Spielberg validado (ID: 154395)\n\nPara obtener información detallada sobre sus colaboraciones, necesitarías consultar una base de datos o herramienta especializada que no está disponible en este sistema de validación.'}]}...
# [VALIDATION] ✅ Validación completada
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Con quién ha colaborado Steven Spielberg?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# 🔹 DIRECTORS NODE
# ================================================================================
# 📝 Pregunta: ¿Con quién ha colaborado Steven Spielberg?
# 📊 Estado actual:
#    • Task: directors
#    • Tool calls previos: 0
#    • Datos acumulados: 0 caracteres
#
# 🔀 Routing a tool específica...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_collaborators   💡 LLM sugiere: get_director_collaborators
#    ⏱️  Tiempo de respuesta: 1.15s
#    ✅ Tool válida, usando: get_director_collaborators
# ✅ Tool seleccionada: get_director_collaborators
# 🤖 Ejecutando tool con Agent (modelo: us.anthropic.claude-3-5-haiku-20241022-v1:0)...
# Tengo un enfoque sistemático para responder esta pregunta. Como primer paso, necesito obtener los co-directores de Steven Spielberg usando su ID numérico.
# Tool #1: get_director_collaborators
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_collaborators_615683
# 📄 Query:
#
#     WITH director_films AS (
#         SELECT uid
#         FROM ms.directed_by
#         WHERE director_id = %s
#     )
#     SELECT
#         d.id AS co_director_id,
#         d.name AS co_director_name,
#         COUNT(DISTINCT df.uid) AS shared_titles
#     FROM director_films df
#     INNER JOIN ms.directed_by dt ON df.uid = dt.uid
#     INNER JOIN ms.directors d ON d.id = dt.director_id
#     WHERE dt.director_id != %s
#     GROUP BY d.id, d.name
#     HAVING COUNT(DISTINCT df.uid) > 0
#     ORDER BY shared_titles DESC, d.name
#     LIMIT %s
#
# 🔧 Parámetros: (615683, 615683, 20)
# ================================================================================
#
# ✅ Query retornó 20 filas en 0.557s
#
# Basándome en los resultados, Steven Spielberg ha colaborado con varios directores. Aquí están algunos de sus principales co-directores:
#
# Colaboraciones más frecuentes (2 títulos compartidos):
# 1. Greta Gerwig
# 2. Jose Villalba
# 3. Lynne Ramsay
# 4. Ridley Scott
# 5. Toby Macdonald
#
# Otros colaboradores notables (1 título compartido):
# - Danny DeVito
# - Gene Stupnitsky
# - Jerry Zaks
# - Brian Percival
# - Andrea Arnold
#
# Es importante notar que esta lista muestra los directores con los que ha trabajado en proyectos conjuntos, lo cual puede incluir diferentes tipos de colaboraciones como producción, dirección o asesoría.
#
# La diversidad de directores sugiere que Spielberg tiene una amplia red de colaboración en la industria cinematográfica, trabajando con talentos de diferentes estilos y orígenes.
#
# ¿Te gustaría que profundice en alguna de estas colaboraciones en particular?📦 Datos obtenidos: 2 caracteres
# 📄 Datos: {'role': 'assistant', 'content': [{'text': 'Basándome en los resultados, Steven Spielberg ha colaborado con varios directores. Aquí están algunos de sus principales co-directores:\n\nColaboraciones más frecuentes (2 títulos compartidos):\n1. Greta Gerwig\n2. Jose Villalba\n3. Lynne Ramsay\n4. Ridley Scott\n5. Toby Macdonald\n\nOtros colaboradores notables (1 título compartido):\n- Danny DeVito\n- Gene Stupnitsky\n- Jerry Zaks\n- Brian Percival\n- Andrea Arnold\n\nEs importante notar que esta lista muestra los directores con los que ha trabajado en proyectos conjuntos, lo cual puede incluir diferentes tipos de colaboraciones como producción, dirección o asesoría.\n\nLa diversidad de directores sugiere que Spielberg tiene una amplia red de colaboración en la industria cinematográfica, trabajando con talentos de diferentes estilos y orígenes.\n\n¿Te gustaría que profundice en alguna de estas colaboraciones en particular?'}]}
#
# ✅ Directors node completado
#    • Total tool calls: 1
#    • Total datos acumulados: 979 caracteres
#    • Último nodo: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# COMPLETO[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'COMPLETO'}]}
# [SUPERVISOR] ✓ Pregunta respondida, ir a format
# Platform Plan: $0.00 USD
# Basándose en los datos proporcionados, Steven Spielberg ha colaborado con los siguientes directores:
#
# Colaboraciones más frecuentes (2 títulos compartidos):
# 1. Greta Gerwig
# 2. Jose Villalba
# 3. Lynne Ramsay
# 4. Ridley Scott
# 5. Toby Macdonald
#
# Otros colaboradores notables (1 título compartido):
# - Danny DeVito
# - Gene Stupnitsky
# - Jerry Zaks
# - Brian Percival
# - Andrea Arnold
# ================================================================================
# 📊 RESULTADO
# ================================================================================
# ✅ Respuesta: {'role': 'assistant', 'content': [{'text': 'Platform Plan: $0.00 USD\nBasándose en los datos proporcionados, Steven Spielberg ha colaborado con los siguientes directores:\n\nColaboraciones más frecuentes (2 títulos compartidos):\n1. Greta Gerwig\n2. Jose Villalba \n3. Lynne Ramsay\n4. Ridley Scott\n5. Toby Macdonald\n\nOtros colaboradores notables (1 título compartido):\n- Danny DeVito\n- Gene Stu...
#
# 📋 Metadata:
#    • Grafo usado: N/A
#    • Validación realizada: True
#    • Tool calls: 0
#    • Re-routings: 0
# ================================================================================

# %%
# Test 1.3: Actor Filmography
result_1_3 = await test_question(
    question="¿En qué películas ha actuado Tom Hanks?"
)
# Out:
# ================================================================================
# ================================================================================
# ❓ Pregunta: ¿En qué películas ha actuado Tom Hanks?
# ================================================================================
#
# ⚠️  Creando grafo con flujo SECUENCIAL (legacy)
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿En qué películas ha actuado Tom Hanks?
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: ¿En qué películas ha actuado Tom Hanks?
# [VALIDATION] 🤖 Ejecutando validación con LLM...
# NO_VALIDATION_NEEDED
#
# Primero voy a validar el actor para asegurar su identificación única:
# Tool #1: validate_actor
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: actor exact search
# 📄 Query:
#
# SELECT id, name
# FROM ms.cast
# WHERE name ILIKE %s
# ORDER BY name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Tom Hanks',)
# ================================================================================
#
# ✅ Query retornó 1 filas en 1.893s
#
# Tom Hanks validado (ID: 805619)
#
# Sin embargo, para listar todas sus películas necesitaría una herramienta adicional que no está disponible en este conjunto de funciones. La función actual solo valida la existencia del actor, pero no recupera su filmografía.
#
# Si deseas saber en qué películas específicas ha actuado Tom Hanks, te recomendaría consultar una base de datos de películas o un sitio web especializado en filmografías de actores.[VALIDATION] 📦 Resultado de validación:
#    {'role': 'assistant', 'content': [{'text': 'Tom Hanks validado (ID: 805619)\n\nSin embargo, para listar todas sus películas necesitaría una herramienta adicional que no está disponible en este conjunto de funciones. La función actual solo valida la existencia del actor, pero no recupera su filmograf...
# [VALIDATION] ✅ Validación completada
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿En qué películas ha actuado Tom Hanks?
# ACTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'ACTORS'}]}
# [TALENT CLASSIFIER] Task final: actors
#
# ================================================================================
# [ACTORS NODE]
# ================================================================================
# Question: ¿En qué películas ha actuado Tom Hanks?
# Current state:
#    • Task: actors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_actor_coactors, get_actor_coactors_by_name, get_actor_filmography, get_actor_filmography_by_name
# get_actor_filmography_by_name   💡 LLM sugiere: get_actor_filmography_by_name
#    ⏱️  Tiempo de respuesta: 1.55s
#    ✅ Tool válida, usando: get_actor_filmography_by_name
# [SUCCESS] Tool selected: get_actor_filmography_by_name
# [ERROR] Tool not found: get_actor_filmography_by_name
# [SUPERVISOR] Evaluando estado... tools=1, task=actors
# [SUPERVISOR] No hay datos suficientes, volviendo al main router
# ⚠️ Talent graph no completó, volviendo al main router...
# 🔄 Re-routing #1 al main_router...
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿En qué películas ha actuado Tom Hanks?
# 🔄 REROUTING #1 desde talent_graph
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿En qué películas ha actuado Tom Hanks?
# ACTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'ACTORS'}]}
# [TALENT CLASSIFIER] Task final: actors
#
# ================================================================================
# [ACTORS NODE]
# ================================================================================
# Question: ¿En qué películas ha actuado Tom Hanks?
# Current state:
#    • Task: actors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_actor_coactors, get_actor_coactors_by_name, get_actor_filmography, get_actor_filmography_by_name
# get_actor_filmography_by_name   💡 LLM sugiere: get_actor_filmography_by_name
#    ⏱️  Tiempo de respuesta: 1.66s
#    ✅ Tool válida, usando: get_actor_filmography_by_name
# [SUCCESS] Tool selected: get_actor_filmography_by_name
# [ERROR] Tool not found: get_actor_filmography_by_name
# [SUPERVISOR] Evaluando estado... tools=1, task=actors
# [SUPERVISOR] No hay datos suficientes, volviendo al main router
# ⚠️ Talent graph no completó, volviendo al main router...
# 🔄 Re-routing #2 al main_router...
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿En qué películas ha actuado Tom Hanks?
# 🔄 REROUTING #2 desde talent_graph
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿En qué películas ha actuado Tom Hanks?
# ACTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'ACTORS'}]}
# [TALENT CLASSIFIER] Task final: actors
#
# ================================================================================
# [ACTORS NODE]
# ================================================================================
# Question: ¿En qué películas ha actuado Tom Hanks?
# Current state:
#    • Task: actors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_actor_coactors, get_actor_coactors_by_name, get_actor_filmography, get_actor_filmography_by_name
# get_actor_filmography_by_name   💡 LLM sugiere: get_actor_filmography_by_name
#    ⏱️  Tiempo de respuesta: 1.21s
#    ✅ Tool válida, usando: get_actor_filmography_by_name
# [SUCCESS] Tool selected: get_actor_filmography_by_name
# [ERROR] Tool not found: get_actor_filmography_by_name
# [SUPERVISOR] Evaluando estado... tools=1, task=actors
# [SUPERVISOR] No hay datos suficientes, volviendo al main router
# ⚠️ Talent graph no completó, volviendo al main router...
# ⚠️ Límite de re-routings alcanzado, terminando...
#
# ================================================================================
# 📊 RESULTADO
# ================================================================================
# ✅ Respuesta: ...
#
# 📋 Metadata:
#    • Grafo usado: N/A
#    • Validación realizada: True
#    • Tool calls: 0
#    • Re-routings: 0
# ================================================================================

# %%
# Test 1.4: Actor Coactors
result_1_4 = await test_question(
    question="¿Con quién ha actuado Brad Pitt frecuentemente?"
)
# Out:
# ================================================================================
# ================================================================================
# ❓ Pregunta: ¿Con quién ha actuado Brad Pitt frecuentemente?
# ================================================================================
#
# ⚠️  Creando grafo con flujo SECUENCIAL (legacy)
#
# ================================================================================
# 🎯 MAIN GRAPH ROUTER
# ================================================================================
# 📝 Pregunta: ¿Con quién ha actuado Brad Pitt frecuentemente?
# TALENT[ROUTER] Decisión raw: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'TALENT'}]}
# [ROUTER] ✅ Grafo seleccionado: talent
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: ¿Con quién ha actuado Brad Pitt frecuentemente?
# [VALIDATION] 🤖 Ejecutando validación con LLM...
# NO_VALIDATION_NEEDED
#
# La pregunta requeriría un análisis de la carrera de Brad Pitt que va más allá de una simple validación de entidad. Para responder a esta pregunta necesitaríamos herramientas adicionales de búsqueda de información sobre filmografía y colaboraciones, que no están disponibles en el conjunto de herramientas actual.
#
# Sin embargo, si deseas que valide el nombre de Brad Pitt como actor, puedo hacerlo:
# Tool #1: validate_actor
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: actor exact search
# 📄 Query:
#
# SELECT id, name
# FROM ms.cast
# WHERE name ILIKE %s
# ORDER BY name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Brad Pitt',)
# ================================================================================
#
# ✅ Query retornó 1 filas en 1.646s
#
# Brad Pitt validado (ID: 1302077)[VALIDATION] 📦 Resultado de validación:
#    {'role': 'assistant', 'content': [{'text': 'Brad Pitt validado (ID: 1302077)'}]}...
# [VALIDATION] ✅ Validación completada
# ================================================================================
#
#
# 🎬 Ejecutando TALENT GRAPH...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Con quién ha actuado Brad Pitt frecuentemente?
# ACTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'ACTORS'}]}
# [TALENT CLASSIFIER] Task final: actors
#
# ================================================================================
# 🔹 ACTORS NODE
# ================================================================================
# 📝 Pregunta: ¿Con quién ha actuado Brad Pitt frecuentemente?
# 📊 Estado actual:
#    • Task: actors
#    • Tool calls previos: 0
#    • Datos acumulados: 0 caracteres
#
# 🔀 Routing a tool específica...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_actor_coactors, get_actor_coactors_by_name, get_actor_filmography, get_actor_filmography_by_name
# get_actor_coactors_by_name   💡 LLM sugiere: get_actor_coactors_by_name
#    ⏱️  Tiempo de respuesta: 1.58s
#    ✅ Tool válida, usando: get_actor_coactors_by_name
# ✅ Tool seleccionada: get_actor_coactors_by_name
# 🤖 Ejecutando tool con Agent (modelo: us.anthropic.claude-3-5-haiku-20241022-v1:0)...
# 📋 Usando entidades validadas del preprocessor (ID: 1302077)
# I'll help you find out Brad Pitt's frequent co-actors by using the get_actor_coactors_by_name tool with his validated actor ID.
# Tool #1: get_actor_coactors_by_name
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: actor_coactors_1302077
# 📄 Query:
#
#     WITH actor_films AS (
#         SELECT uid
#         FROM ms.acted_in
#         WHERE cast_id = %s
#     )
#     SELECT
#         c.id AS co_actor_id,
#         c.name AS co_actor_name,
#         COUNT(DISTINCT af.uid) AS films_together
#     FROM actor_films af
#     INNER JOIN ms.acted_in ai ON af.uid = ai.uid
#     INNER JOIN ms.cast c ON ai.cast_id = c.id
#     WHERE ai.cast_id != %s
#     GROUP BY c.id, c.name
#     HAVING COUNT(DISTINCT af.uid) > 1
#     ORDER BY films_together DESC, c.name, c.id
#     LIMIT %s
#
# 🔧 Parámetros: (1302077, 1302077, 15)
# ================================================================================
#
# ✅ Query retornó 15 filas en 2.791s
#
# Basándome en los resultados, aquí están los co-actores más frecuentes de Brad Pitt:
#
# 1. George Clooney (20 películas juntos)
# 2. Angelina Jolie (17 películas juntos)
# 3. Leonardo DiCaprio (13 películas juntos)
# 4. Tom Hanks (11 películas juntos)
# 5. Jennifer Aniston (10 películas juntos)
# 6. Robert De Niro (10 películas juntos)
# 7. Tom Cruise (10 películas juntos)
#
# Es interesante notar que Brad Pitt ha colaborado extensamente con George Clooney, con quien ha trabajado en 20 películas, principalmente en la saga Ocean's (Ocean's Eleven, Twelve, Thirteen). También ha tenido una larga colaboración cinematográfica con su ex-esposa Angelina Jolie, con 17 películas en conjunto.
#
# Otros actores destacados con quienes ha trabajado frecuentemente incluyen a Leonardo DiCaprio, Tom Hanks, y Matt Damon, lo que sugiere que Brad Pitt tiene una amplia red de colaboraciones en Hollywood.📦 Datos obtenidos: 2 caracteres
# 📄 Datos: {'role': 'assistant', 'content': [{'text': "Basándome en los resultados, aquí están los co-actores más frecuentes de Brad Pitt:\n\n1. George Clooney (20 películas juntos)\n2. Angelina Jolie (17 películas juntos)\n3. Leonardo DiCaprio (13 películas juntos)\n4. Tom Hanks (11 películas juntos)\n5. Jennifer Aniston (10 películas juntos)\n6. Robert De Niro (10 películas juntos)\n7. Tom Cruise (10 películas juntos)\n\nEs interesante notar que Brad Pitt ha colaborado extensamente con George Clooney, con quien ha trabajado en 20 películas, principalmente en la saga Ocean's (Ocean's Eleven, Twelve, Thirteen). También ha tenido una larga colaboración cinematográfica con su ex-esposa Angelina Jolie, con 17 películas en conjunto.\n\nOtros actores destacados con quienes ha trabajado frecuentemente incluyen a Leonardo DiCaprio, Tom Hanks, y Matt Damon, lo que sugiere que Brad Pitt tiene una amplia red de colaboraciones en Hollywood."}]}
#
# ✅ Actors node completado
#    • Total tool calls: 1
#    • Total datos acumulados: 977 caracteres
#    • Último nodo: actors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=actors
# COMPLETO[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'COMPLETO'}]}
# [SUPERVISOR] ✓ Pregunta respondida, ir a format
# George Clooney (20 películas)
# Angelina Jolie (17 películas)
# Leonardo DiCaprio (13 películas)
# Tom Hanks (11 películas)
# Jennifer Aniston (10 películas)
# Robert De Niro (10 películas)
# Tom Cruise (10 películas)
# ================================================================================
# 📊 RESULTADO
# ================================================================================
# ✅ Respuesta: {'role': 'assistant', 'content': [{'text': 'George Clooney (20 películas)\nAngelina Jolie (17 películas)\nLeonardo DiCaprio (13 películas)\nTom Hanks (11 películas)\nJennifer Aniston (10 películas)\nRobert De Niro (10 películas)\nTom Cruise (10 películas)'}]}...
#
# 📋 Metadata:
#    • Grafo usado: N/A
#    • Validación realizada: True
#    • Tool calls: 0
#    • Re-routings: 0
# ================================================================================

# %%
# Test 1.5: Actor-Director Collaborations
result_1_5 = await test_question(
    question="¿En qué películas han trabajado juntos Leonardo DiCaprio y Martin Scorsese?",
    expected_graph="talent",
    description="Actor-Director Collaborations"
)

# %% [markdown]
# ## 2. CONTENT Graph Tests
#
# ### Flujo esperado:
# ```
# Main Router → CONTENT
#     ↓
# Validation → validate_title (si menciona título específico)
#     ↓
# Content Classifier → metadata/discovery
#     ↓
# Router → Selecciona tool específica
#     ↓
# Agent → Ejecuta y responde
# ```

# %%
# Test 2.1: Metadata Query - Year
result_2_1 = await test_question(
    question="¿De qué año es Inception?",
    expected_graph="content",
    description="Metadata Query - Year of Inception"
)

# %%
# Test 2.2: Metadata Count
result_2_2 = await test_question(
    question="¿Cuántas películas de acción hay en el catálogo?",
    expected_graph="content",
    description="Metadata Count - Action Movies"
)

# %%
# Test 2.3: Metadata List
result_2_3 = await test_question(
    question="¿Qué géneros están disponibles?",
    expected_graph="content",
    description="Metadata List - Available Genres"
)

# %%
# Test 2.4: Metadata Stats
result_2_4 = await test_question(
    question="Dame estadísticas del catálogo de películas",
    expected_graph="content",
    description="Metadata Stats - Catalog Statistics"
)

# %%
# Test 2.5: Discovery - Filmography by UID
result_2_5 = await test_question(
    question="Dame información completa de The Matrix",
    expected_graph="content",
    description="Discovery - Complete Info"
)

# %% [markdown]
# ## 3. PLATFORM Graph Tests
#
# ### Flujo esperado:
# ```
# Main Router → PLATFORM
#     ↓
# Validation → validate_title (para availability)
#     ↓
# Platform Classifier → availability/presence
#     ↓
# Router → Selecciona tool específica
#     ↓
# Agent → Ejecuta y responde
# ```

# %%
# Test 3.1: Availability by Title
result_3_1 = await test_question(
    question="¿Dónde puedo ver The Matrix?",
    expected_graph="platform",
    description="Availability - The Matrix"
)

# %%
# Test 3.2: Platform Exclusives
result_3_2 = await test_question(
    question="¿Qué contenido exclusivo tiene Netflix en Estados Unidos?",
    expected_graph="platform",
    description="Platform Exclusives - Netflix US"
)

# %%
# Test 3.3: Presence Count
result_3_3 = await test_question(
    question="¿Cuántos títulos tiene Disney+ en Argentina?",
    expected_graph="platform",
    description="Presence Count - Disney+ Argentina"
)

# %%
# Test 3.4: Presence Statistics
result_3_4 = await test_question(
    question="Dame estadísticas de contenido en plataformas de streaming",
    expected_graph="platform",
    description="Presence Statistics - Overall"
)

# %%
# Test 3.5: Recent Premieres
result_3_5 = await test_question(
    question="¿Qué estrenos recientes hay en México?",
    expected_graph="platform",
    description="Recent Premieres - Mexico"
)

# %% [markdown]
# ## 4. BUSINESS Graph Tests
#
# ### Flujo esperado:
# ```
# Main Router → BUSINESS
#     ↓
# Business Classifier → pricing/rankings/intelligence
#     ↓
# Router → Selecciona tool específica
#     ↓
# Agent → Ejecuta y responde
# ```

# %%
# Test 4.1: Pricing - Latest
result_4_1 = await test_question(
    question="¿Cuál es el precio actual de Netflix?",
    expected_graph="business",
    description="Pricing - Netflix Latest"
)

# %%
# Test 4.2: Pricing - Historical
result_4_2 = await test_question(
    question="¿Cómo ha evolucionado el precio de Disney+ en el último año?",
    expected_graph="business",
    description="Pricing - Disney+ Historical"
)

# %%
# Test 4.3: Rankings - Top Generic
result_4_3 = await test_question(
    question="¿Cuáles son las películas más populares?",
    expected_graph="business",
    description="Rankings - Top Movies"
)

# %%
# Test 4.4: Intelligence - Catalog Similarity
result_4_4 = await test_question(
    question="¿Qué tan similar es el catálogo de Netflix y HBO Max?",
    expected_graph="business",
    description="Intelligence - Catalog Similarity"
)

# %% [markdown]
# ## 5. Desambiguación Tests
#
# ### Flujo esperado:
# ```
# Main Router → Grafo
#     ↓
# Validation → Detecta múltiples coincidencias
#     ↓
# Sistema retorna needs_user_input = True
#     ↓
# Usuario elige opción
#     ↓
# Segunda llamada con resolved_entity
#     ↓
# Continúa flujo normal
# ```

# %%
# Test 5.1: Título ambiguo
result_5_1 = await test_question(
    question="¿De qué año es The Matrix?",
    expected_graph="content",
    description="Disambiguation - The Matrix (múltiples versiones)"
)

# %%
# Test 5.2: Actor ambiguo (si existe)
result_5_2 = await test_question(
    question="¿Qué películas ha hecho Michael Jordan?",
    expected_graph="talent",
    description="Disambiguation - Michael Jordan (actor vs deportista)"
)

# %% [markdown]
# ## 📊 Resumen de Resultados

# %%
# Recopilar todos los resultados
all_results = [
    result_1_1, result_1_2, result_1_3, result_1_4, result_1_5,  # TALENT
    result_2_1, result_2_2, result_2_3, result_2_4, result_2_5,  # CONTENT
    result_3_1, result_3_2, result_3_3, result_3_4, result_3_5,  # PLATFORM
    result_4_1, result_4_2, result_4_3, result_4_4,              # BUSINESS
    result_5_1, result_5_2                                        # DISAMBIGUATION
]

# Contar por status
success_count = sum(1 for r in all_results if r['status'] == 'success')
error_count = sum(1 for r in all_results if r['status'] == 'error')
disambiguation_count = sum(1 for r in all_results if r['status'] == 'disambiguation')
total = len(all_results)

print("\n" + "="*80)
print("📊 RESUMEN FINAL DE TESTS")
print("="*80)
print(f"\n✅ Exitosos: {success_count}/{total} ({success_count/total*100:.1f}%)")
print(f"⚠️  Desambiguación: {disambiguation_count}/{total} ({disambiguation_count/total*100:.1f}%)")
print(f"❌ Errores: {error_count}/{total} ({error_count/total*100:.1f}%)")

print("\n" + "-"*80)
print("📋 Detalle por Grafo:")
print("-"*80)

# Agrupar por grafo
by_graph = {}
for r in all_results:
    graph = r['expected_graph']
    if graph not in by_graph:
        by_graph[graph] = {'success': 0, 'error': 0, 'disambiguation': 0, 'total': 0}
    by_graph[graph][r['status']] += 1
    by_graph[graph]['total'] += 1

for graph, stats in by_graph.items():
    success_pct = stats['success'] / stats['total'] * 100
    print(f"\n🔹 {graph.upper()}:")
    print(f"   ✅ {stats['success']}/{stats['total']} exitosos ({success_pct:.1f}%)")
    if stats['disambiguation'] > 0:
        print(f"   ⚠️  {stats['disambiguation']} con desambiguación")
    if stats['error'] > 0:
        print(f"   ❌ {stats['error']} con errores")

print("\n" + "="*80 + "\n")

# %% [markdown]
# ## 🔍 Análisis de Errores

# %%
# Mostrar detalles de errores
errors = [r for r in all_results if r['status'] == 'error']

if errors:
    print("\n" + "="*80)
    print("❌ ERRORES ENCONTRADOS")
    print("="*80)
    
    for i, err in enumerate(errors, 1):
        print(f"\n{i}. {err['question']}")
        print(f"   Grafo esperado: {err['expected_graph']}")
        print(f"   Error: {err['error']}")
else:
    print("\n✅ No se encontraron errores")

# %% [markdown]
# ## 📝 Exportar Resultados

# %%
# Guardar resultados en JSON
import json
from datetime import datetime

output = {
    "timestamp": datetime.now().isoformat(),
    "summary": {
        "total": total,
        "success": success_count,
        "disambiguation": disambiguation_count,
        "error": error_count,
        "success_rate": f"{success_count/total*100:.1f}%"
    },
    "by_graph": by_graph,
    "results": all_results
}

with open('test_graph_flows_results.json', 'w', encoding='utf-8') as f:
    json.dump(output, f, indent=2, ensure_ascii=False)

print("\n✅ Resultados guardados en: test_graph_flows_results.json")
