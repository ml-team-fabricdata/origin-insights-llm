# %% [markdown]
# # 🧪 Test Interactivo del Grafo V2.1
#
# **Versión:** V2.1 con Reglas Determinísticas
# **Fecha:** 2025-10-14
#
# ---
#
# ## 📋 Características del Sistema
#
# ### **Router**
# - ✅ Top-K dinámico: `score2 >= score1 - 0.10` → K=2, sino K=1
# - ✅ Tracking: visited, hops, MAX_HOPS=2
#
# ### **Parallel Executor**
# - ✅ STOP_AFTER = 0.85: Cancela si resolved >= 0.85
# - ✅ TOOL_TIMEOUT = 2s por tool
# - ✅ BUDGET_TOOLS_PER_TURN = 6 tools máximo
#
# ### **Aggregator**
# - ✅ Umbrales calibrados: talent=0.75, platform=0.70, business=0.70, content=0.68
# - ✅ common_graph nunca ganador final
# - ✅ MAX_HOPS = 2 re-routings
#
# ### **Clarifier**
# - ✅ Loop-safe: MAX_HOPS=2
# - ✅ Máximo 2 campos de clarificación

# %% [markdown]
# ## 1. Setup - Imports y Configuración

# %%
from src.strands.main_router.graph import process_question_advanced

# Uso simple
result = await process_question_advanced(
    question="peliculas de coppola",
    max_hops=2
)

print(result['answer'])
# Out:
# Loading validation data from platform_name_iso
#
# ================================================================================
# 🎯 ADVANCED ROUTER
# ================================================================================
# 📝 Pregunta: peliculas de coppola
# {
#   "primary": "TALENT",
#   "confidence": 0.90,
#   "candidates": [
#     {"category": "TALENT", "confidence": 0.90}
#   ]
# }[ROUTER] ✅ Grafo seleccionado: talent
# [ROUTER] 📊 Confidence: 0.90
# [ROUTER] 🔢 Candidatos: 1
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: peliculas de coppola
# [VALIDATION] 🤖 Ejecutando validación con LLM...
# Para validar los directores de Coppola, usaré la herramienta validate_director:
# Tool #1: validate_director
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director exact search
# 📄 Query:
#
# WITH q AS (SELECT %s::text AS s)
# SELECT
#   d.id,
#   d.name,
#   t.n_titles
# FROM ms.directors d
# CROSS JOIN q
# LEFT JOIN LATERAL (
#   SELECT COUNT(*)::integer AS n_titles
#   FROM ms.directed_by db
#   WHERE db.director_id = d.id
# ) t ON TRUE
# WHERE d.name ILIKE q.s
# ORDER BY t.n_titles DESC NULLS LAST, d.name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Coppola',)
# ================================================================================
#
# ✅ Query retornó 0 filas en 1.010s
#
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director fuzzy search (threshold 0.38)
# 📄 Query:
#
# WITH q AS (SELECT %s::text AS s)
# SELECT
#   d.id,
#   d.name,
#   0.0 AS sim,
#   t.n_titles
# FROM ms.directors d
# CROSS JOIN q
# LEFT JOIN LATERAL (
#   SELECT COUNT(*)::integer AS n_titles
#   FROM ms.directed_by db
#   WHERE db.director_id = d.id
# ) t ON TRUE
# WHERE d.name ILIKE '%%' || q.s || '%%'
# ORDER BY
#   CASE WHEN d.name ILIKE q.s || '%%' THEN 1 ELSE 2 END,
#   t.n_titles DESC NULLS LAST,
#   d.name ASC
# LIMIT 25
#
# 🔧 Parámetros: ('Coppola',)
# ================================================================================
#
# ✅ Query retornó 25 filas en 14.791s
#
# Múltiples resultados para "Coppola":
# 1. Coppola Francis Ford
# 2. Francis Ford Coppola
# 3. Sofia Coppola
# 4. Gia Coppola
# 5. Eleanor Coppola
# ¿Cuál es? (1..5)[VALIDATION] 📦 Resultado de validación:
#    {'role': 'assistant', 'content': [{'text': 'Múltiples resultados para "Coppola":\n1. Coppola Francis Ford\n2. Francis Ford Coppola\n3. Sofia Coppola\n4. Gia Coppola\n5. Eleanor Coppola\n¿Cuál es? (1..5)'}]}...
# [VALIDATION] ⚠️ Ambigüedad detectada - requiere input del usuario
# ================================================================================
#
#
# ================================================================================
# 🔍 DISAMBIGUATION NODE
# ================================================================================
# [DISAMBIGUATION] Mensaje formateado
# ================================================================================
#
# 🔍 **Disambiguation Required**
#
# {'role': 'assistant', 'content': [{'text': 'Múltiples resultados para "Coppola":\n1. Coppola Francis Ford\n2. Francis Ford Coppola\n3. Sofia Coppola\n4. Gia Coppola\n5. Eleanor Coppola\n¿Cuál es? (1..5)'}]}
#
# Please specify which option you meant, and I'll continue with your query.

# %%
# Uso simple
result = await process_question_advanced(
    question="1",
    max_hops=2
)

print(result['answer'])
# Out:
# ================================================================================
# 🎯 ADVANCED ROUTER
# ================================================================================
# 📝 Pregunta: 1
# {
#   "primary": "COMMON",
#   "confidence": 0.75,
#   "candidates": [
#     {"category": "COMMON", "confidence": 0.75},
#     {"category": "PLATFORM", "confidence": 0.5}
#   ]
# }[ROUTER] ✅ Grafo seleccionado: common
# [ROUTER] 📊 Confidence: 0.75
# [ROUTER] 🔢 Candidatos: 2
# [ROUTER] ⏭️  Validación no requerida
# ================================================================================
#
#
# ================================================================================
# 🔍 VALIDATION PREPROCESSOR
# ================================================================================
# 📝 Pregunta: 1
# [VALIDATION] ⏭️  Validación no requerida para este grafo, saltando...
#
# ================================================================================
# 🎬 DOMAIN GRAPH EXECUTOR
# ================================================================================
# [DOMAIN] Ejecutando: common
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# ADMIN
# ================================================================================
# [ADMIN NODE]
# ================================================================================
# Question: 1
# Current state:
#    • Task: admin
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: build_sql, run_sql_adapter, validate_intent
# admin_validate_intent   💡 LLM sugiere: admin_validate_intent
#    ⏱️  Tiempo de respuesta: 1.07s
#    ❌ Tool inválida: 'admin_validate_intent'. Tools válidas: build_sql, run_sql_adapter, validate_intent
# [DOMAIN] ❌ Error: ❌ Tool inválida: 'admin_validate_intent'. Tools válidas: build_sql, run_sql_adapter, validate_intent
# ================================================================================
#
#
# ================================================================================
# ⚠️ ERROR HANDLER
# ================================================================================
# [ERROR_HANDLER] Error: ❌ Tool inválida: 'admin_validate_intent'. Tools válidas: build_sql, run_sql_adapter, validate_intent
# ================================================================================
#
# ⚠️ **System Error**
#
# I encountered an error while processing your question.
#
# **Your question:** 1
#
# **Error:** ❌ Tool inválida: 'admin_validate_intent'. Tools válidas: build_sql, run_sql_adapter, validate_intent
#
# Please try rephrasing your question or contact support if the issue persists.

# %%
import sys
import asyncio
from pathlib import Path
import json
from datetime import datetime

# Agregar src al path si no está
if str(Path.cwd()) not in sys.path:
    sys.path.insert(0, str(Path.cwd()))

# Imports del sistema
from src.strands.main_router.graph import create_main_graph, process_question
from src.strands.main_router.aggregator import THRESHOLD_BY_NODE, MAX_HOPS
from src.strands.main_router.parallel_executor import TOOL_TIMEOUT, BUDGET_TOOLS_PER_TURN, STOP_AFTER

print("✅ Imports completados")
print(f"\n📊 Configuración:")
print(f"  • Umbrales: {THRESHOLD_BY_NODE}")
print(f"  • MAX_HOPS: {MAX_HOPS}")
print(f"  • TOOL_TIMEOUT: {TOOL_TIMEOUT}s")
print(f"  • BUDGET: {BUDGET_TOOLS_PER_TURN} tools")
print(f"  • STOP_AFTER: {STOP_AFTER}")
# Out:
# Loading validation data from platform_name_iso
# ✅ Imports completados
#
# 📊 Configuración:
#   • Umbrales: {'platform_graph': 0.7, 'business_graph': 0.7, 'talent_graph': 0.75, 'content_graph': 0.68, 'common_graph': None}
#   • MAX_HOPS: 2
#   • TOOL_TIMEOUT: 2.0s
#   • BUDGET: 6 tools
#   • STOP_AFTER: 0.85

# %% [markdown]
# ## 2. Crear Grafo

# %%
# Crear grafo
try:
    graph = create_main_graph()
    print("✅ Grafo creado correctamente")
except Exception as e:
    print(f"❌ Error al crear grafo: {e}")
    raise
# Out:
# ✅ Grafo creado correctamente

# %% [markdown]
# ## 3. Función Helper para Testear

# %%
def print_result(result, question):
    """
    Imprime resultado de manera legible.
    """
    print("\n" + "="*80)
    print(f"📝 PREGUNTA: {question}")
    print("="*80)
    
    # Respuesta
    answer = result.get("answer", "Sin respuesta")
    print(f"\n💬 RESPUESTA:\n{answer}")
    
    # Metadata del router
    print(f"\n🎯 ROUTER:")
    routing_scores = result.get("routing_scores", {})
    if routing_scores:
        sorted_scores = sorted(routing_scores.items(), key=lambda x: x[1], reverse=True)
        for graph, score in sorted_scores[:3]:
            print(f"  • {graph}: {score:.2f}")
    
    selected = result.get("selected_candidates", [])
    if selected:
        print(f"  ✅ Seleccionados: {[f'{g}({s:.2f})' for g, s in selected]}")
    
    # Metadata del aggregator
    print(f"\n⚖️ AGGREGATOR:")
    decision = result.get("aggregator_decision", "N/A")
    print(f"  • Decisión: {decision}")
    
    winning_node = result.get("winning_node")
    if winning_node:
        confidence = result.get("final_confidence", 0)
        threshold = result.get("threshold_used", 0)
        print(f"  • Ganador: {winning_node}")
        print(f"  • Confidence: {confidence:.3f} >= {threshold:.3f}")
    
    # Telemetría
    print(f"\n📊 TELEMETRÍA:")
    tools_used = result.get("tools_used", 0)
    budget_exhausted = result.get("budget_exhausted", False)
    print(f"  • Tools usados: {tools_used}/{BUDGET_TOOLS_PER_TURN}")
    print(f"  • Budget agotado: {budget_exhausted}")
    
    cancelled = result.get("cancelled_branch")
    if cancelled:
        print(f"  • Branch cancelado: {cancelled} (STOP_AFTER)")
    
    lat_parallel = result.get("lat_parallel")
    lat_aggregator = result.get("lat_aggregator")
    if lat_parallel:
        print(f"  • Latencia parallel: {lat_parallel:.3f}s")
    if lat_aggregator:
        print(f"  • Latencia aggregator: {lat_aggregator:.3f}s")
    
    # Re-routing
    hops = result.get("rerouting_count", 0)
    visited = result.get("visited_graphs", [])
    print(f"  • Hops: {hops}/{MAX_HOPS}")
    if visited:
        print(f"  • Visited: {visited}")
    
    # Clarificación
    needs_clarification = result.get("needs_clarification", False)
    if needs_clarification:
        reason = result.get("clarification_reason", "unknown")
        print(f"\n❓ CLARIFICACIÓN:")
        print(f"  • Razón: {reason}")
    
    print("\n" + "="*80)

print("✅ Helper function definida")
# Out:
# ✅ Helper function definida

# %% [markdown]
# ## 4. Tests de Preguntas
#
# ### 📝 Categorías de Preguntas
#
# 1. **TALENT** - Actores, directores, filmografías
# 2. **CONTENT** - Metadata de títulos (año, género, duración)
# 3. **PLATFORM** - Disponibilidad, dónde ver
# 4. **BUSINESS** - Precios, rankings, popularidad
# 5. **COMMON** - Estadísticas, administración

# %% [markdown]
# ### Test 1: Pregunta TALENT (Alta Confianza)

# %%
# Pregunta sobre director (debería ir a talent_graph)
question = "Informacion de Inception"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: Informacion de Inception
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): N/A
#   • Tipos de entidad: N/A
#   • Tokens: 3
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: Informacion de Inception
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.7,
#   "talent": 0.8,
#   "content": 0.9,
#   "platform": 0.6,
#   "common": 0.3
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.7,\n  "talent": 0.8,\n  "content": 0.9,\n  "platform": 0.6,\n  "common": 0.3\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.7,\n  "talent": 0.8,\n  "content": 0.9,\n  "platform": 0.6,\n  "common": 0.3\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: Informacion de Inception
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: Informacion de Inception
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.24s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.738s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: Informacion de Inception
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.8,
#   "talent": 0.7,
#   "content": 0.8,
#   "platform": 0.6,
#   "common": 0.1
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.8,\n  "talent": 0.7,\n  "content": 0.8,\n  "platform": 0.6,\n  "common": 0.1\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.8,\n  "talent": 0.7,\n  "content": 0.8,\n  "platform": 0.6,\n  "common": 0.1\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: Informacion de Inception
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: Informacion de Inception
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.93s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.990s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: Informacion de Inception
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.990s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================

# %%
# Pregunta sobre director (debería ir a talent_graph)
question = "¿Qué películas ha dirigido Christopher Nolan?"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AR', 'BO', 'BR', 'CL', 'CO', 'CR', 'CU', 'DO', 'EC', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'PR', 'PY', 'SV', 'UY', 'VE']
#   • Tipos de entidad: movie
#   • Tokens: 6
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.9,
#   "content": 0.6,
#   "platform": 0.1,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   • platform: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ talent_graph (score: 0.90)
# [DEBUG] selected = [('talent', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('talent', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('talent', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'talent': 0.9, 'content': 0.3, 'business': 0.1, 'platform': 0.1, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('talent', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • talent_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching talent (score: 0.90)
#
# [TALENT GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha dirigido Christopher Nolan?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha dirigido Christopher Nolan?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.87s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Validated director_id: 615683
# Tool #1: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_615683
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (615683, 10)
# ================================================================================
#
# ✅ Query retornó 10 filas en 0.443s
#
# Basándome en los resultados, Christopher Nolan ha dirigido las siguientes películas:
#
# Películas recientes:
# 1. Oppenheimer (2023)
# 2. Tenet (2020)
# 3. Dunkirk (2017)
# 4. Interstellar (2014)
# 5. The Dark Knight Rises (2012)
# 6. Inception (2010)
#
# Otras películas:
# 7. Quay (2015)
# 8. Un proyecto sin título para 2026
#
# También aparece una entrada para "Barbenheimer" de 2023 y una serie llamada "Erlend og Steinar hjelper deg", aunque estos no parecen ser proyectos principales de Nolan.
#
# Su filmografía muestra una trayectoria de películas de ciencia ficción, drama histórico y acción, con múltiples películas aclamadas por la crítica y el público. Es notable su trabajo en películas como Inception, Interstellar y recientemente Oppenheimer.
#
# ¿Le gustaría que profundice en alguna de estas películas en particular?[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Basándome en los resultados, Christopher Nolan ha dirigido las siguientes películas:\n\nPelículas recientes:\n1. Oppenheimer (2023)\n2. Tenet (2020)\n3. Dunkirk (2017)\n4. Interstellar (2014)\n5. The Dark Knight Rises (2012)\n6. Inception (2010)\n\nOtras películas:\n7. Quay (2015)\n8. Un proyecto sin título para 2026\n\nTambién aparece una entrada para "Barbenheimer" de 2023 y una serie llamada "Erlend og Steinar hjelper deg", aunque estos no parecen ser proyectos principales de Nolan.\n\nSu filmografía muestra una trayectoria de películas de ciencia ficción, drama histórico y acción, con múltiples películas aclamadas por la crítica y el público. Es notable su trabajo en películas como Inception, Interstellar y recientemente Oppenheimer.\n\n¿Le gustaría que profundice en alguna de estas películas en particular?'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 930 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# COMPLETO[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'COMPLETO'}]}
# [SUPERVISOR] ✓ Pregunta respondida, ir a format
# Basándose en los datos proporcionados, las películas que ha dirigido Christopher Nolan son:
#
# 1. Oppenheimer (2023)
# 2. Tenet (2020)
# 3. Dunkirk (2017)
# 4. Interstellar (2014)
# 5. The Dark Knight Rises (2012)
# 6. Inception (2010)
# 7. Quay (2015)
# 8. Un proyecto sin título para 2026[TALENT GRAPH] Completed
#   • Status: resolved
#   • Confidence: 0.95
#   • Needs reroute: False
# [PARALLEL EXECUTOR] talent completed:
#   • Status: resolved
#   • Confidence: 0.93 (routing: 0.90, subgraph: 0.95)
# [STOP_AFTER] talent resolved with 0.93 >= 0.85
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 15.879s
# [PARALLEL EXECUTOR] ⚡ Cancelled: STOP_AFTER triggered by talent
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=resolved, confidence=0.93
# [AGGREGATOR] Decision: winner
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] ✅ Winner: unknown
# [AGGREGATOR]    Confidence: 0.925 >= 0.650
# [AGGREGATOR]    Latency: 0.000s
#
# ================================================================================
# 📝 PREGUNTA: ¿Qué películas ha dirigido Christopher Nolan?
# ================================================================================
#
# 💬 RESPUESTA:
# {'role': 'assistant', 'content': [{'text': 'Basándose en los datos proporcionados, las películas que ha dirigido Christopher Nolan son:\n\n1. Oppenheimer (2023)\n2. Tenet (2020)\n3. Dunkirk (2017)\n4. Interstellar (2014)\n5. The Dark Knight Rises (2012)\n6. Inception (2010)\n7. Quay (2015)\n8. Un proyecto sin título para 2026'}]}
#
# 🎯 ROUTER:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   ✅ Seleccionados: ['talent(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: winner
#   • Ganador: unknown
#   • Confidence: 0.925 >= 0.650
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 15.879s
#   • Latencia aggregator: 0.000s
#   • Hops: 0/2
#   • Visited: ['talent']
#
# ================================================================================

# %% [markdown]
# ### Test 2: Pregunta PLATFORM (Alta Confianza)

# %%
# Pregunta sobre disponibilidad (debería ir a platform_graph)
question = "¿Dónde puedo ver Stranger Things en Argentina?"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Stranger Things en Argentina?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
#   • Tipos de entidad: country
#   • Tokens: 7
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Stranger Things en Argentina?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.1,
#   "content": 0.3,
#   "platform": 0.8,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.3,\n  "platform": 0.8,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.3,\n  "platform": 0.8,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Dónde puedo ver Stranger Things en Argentina?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Dónde puedo ver Stranger Things en Argentina?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.48s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.370s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Stranger Things en Argentina?
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.1,
#   "content": 0.4,
#   "platform": 0.8,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.4,\n  "platform": 0.8,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.4,\n  "platform": 0.8,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Dónde puedo ver Stranger Things en Argentina?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Dónde puedo ver Stranger Things en Argentina?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.31s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.119s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: ¿Dónde puedo ver Stranger Things en Argentina?
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.119s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================

# %% [markdown]
# ### Test 3: Pregunta BUSINESS (Precios)

# %%
# Pregunta sobre precios (debería ir a business_graph)
question = "¿Cuánto cuesta Netflix en Argentina?"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta Netflix en Argentina?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
#   • Tipos de entidad: price, platform
#   • Tokens: 5
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta Netflix en Argentina?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.8,
#   "talent": 0.0,
#   "content": 0.0,
#   "platform": 0.9,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.8,\n  "talent": 0.0,\n  "content": 0.0,\n  "platform": 0.9,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.8,\n  "talent": 0.0,\n  "content": 0.0,\n  "platform": 0.9,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   • content: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ business_graph (score: 0.90)
# [DEBUG] selected = [('business', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('business', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('business', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'business': 0.9, 'talent': 0.1, 'content': 0.1, 'platform': 0.2, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('business', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • business_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching business (score: 0.90)
#
# [BUSINESS_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [BUSINESS CLASSIFIER] Clasificando pregunta: ¿Cuánto cuesta Netflix en Argentina?
# PRICING[BUSINESS CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'PRICING'}]}
# [BUSINESS CLASSIFIER] Task final: pricing
#
# ================================================================================
# [PRICING NODE]
# ================================================================================
# Question: ¿Cuánto cuesta Netflix en Argentina?
# Current state:
#    • Task: pricing
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: build_presence_with_price_query, query_presence_with_price, tool_hits_with_quality, tool_prices_changes_last_n_days, tool_prices_history, tool_prices_latest, tool_prices_stats
# query_presence_with_price   💡 LLM sugiere: query_presence_with_price
#    ⏱️  Tiempo de respuesta: 2.02s
#    ✅ Tool válida, usando: query_presence_with_price
# [SUCCESS] Tool selected: query_presence_with_price
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
#
# Tool #1: query_presence_with_price
# I apologize for the error. Let me try again with a different parameter format:
# Tool #2: query_presence_with_price
# I'll modify the approach and use kwargs as a JSON string:
# Tool #3: query_presence_with_price
# I apologize, but I'm encountering persistent technical issues with the query tool. Without being able to retrieve the specific pricing data, I cannot provide the exact current price of Netflix in Argentina.
#
# To get the most accurate and up-to-date pricing, I recommend:
# 1. Checking Netflix's official website for Argentina
# 2. Contacting Netflix customer support directly
# 3. Verifying current pricing through local telecommunications providers[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': "I apologize, but I'm encountering persistent technical issues with the query tool. Without being able to retrieve the specific pricing data, I cannot provide the exact current price of Netflix in Argentina. \n\nTo get the most accurate and up-to-date pricing, I recommend:\n1. Checking Netflix's official website for Argentina\n2. Contacting Netflix customer support directly\n3. Verifying current pricing through local telecommunications providers"}]}
#
# [SUCCESS] Pricing node completed
#    • Total tool calls: 1
#    • Total accumulated data: 555 characters
#    • Last node: pricing_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=pricing
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# [BUSINESS_GRAPH] Completed
#   • Status: not_applicable
#   • Confidence: 0.30
#   • Reason: Graph cannot handle this question
# [PARALLEL EXECUTOR] business completed:
#   • Status: not_applicable
#   • Confidence: 0.60 (routing: 0.90, subgraph: 0.30)
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 16.541s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. business_graph: status=not_applicable, confidence=0.60
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results not_applicable, needs rerouting
#
# ================================================================================
# 📝 PREGUNTA: ¿Cuánto cuesta Netflix en Argentina?
# ================================================================================
#
# 💬 RESPUESTA:
#
#
# 🎯 ROUTER:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   ✅ Seleccionados: ['business(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: need_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 16.541s
#   • Hops: 1/2
#   • Visited: ['business']
#
# ================================================================================

# %% [markdown]
# ### Test 4: Pregunta CONTENT (Metadata)

# %%
# Pregunta sobre metadata (debería ir a content_graph)
question = "¿De qué año es la película Inception?"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿De qué año es la película Inception?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AR', 'BO', 'BR', 'CL', 'CO', 'CR', 'CU', 'DO', 'EC', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'PR', 'PY', 'SV', 'UY', 'VE']
#   • Tipos de entidad: movie
#   • Tokens: 7
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿De qué año es la película Inception?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.1,
#   "talent": 0.2,
#   "content": 0.8,
#   "platform": 0.2,
#   "common": 0.1
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.1,\n  "talent": 0.2,\n  "content": 0.8,\n  "platform": 0.2,\n  "common": 0.1\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.1,\n  "talent": 0.2,\n  "content": 0.8,\n  "platform": 0.2,\n  "common": 0.1\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿De qué año es la película Inception?
# METADATA[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'METADATA'}]}
# [CLASSIFIER] Task final: metadata
#
# ================================================================================
# [METADATA NODE]
# ================================================================================
# Question: ¿De qué año es la película Inception?
# Current state:
#    • Task: metadata
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# metadata_simple_all_stats   💡 LLM sugiere: metadata_simple_all_stats
#    ⏱️  Tiempo de respuesta: 1.28s
#    ❌ Tool inválida: 'metadata_simple_all_stats'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [ERROR] content execution failed: ❌ Tool inválida: 'metadata_simple_all_stats'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 2.679s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿De qué año es la película Inception?
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.1,
#   "talent": 0.2,
#   "content": 0.9,
#   "platform": 0.1,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.1,\n  "talent": 0.2,\n  "content": 0.9,\n  "platform": 0.1,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.1,\n  "talent": 0.2,\n  "content": 0.9,\n  "platform": 0.1,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿De qué año es la película Inception?
# METADATA[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'METADATA'}]}
# [CLASSIFIER] Task final: metadata
#
# ================================================================================
# [METADATA NODE]
# ================================================================================
# Question: ¿De qué año es la película Inception?
# Current state:
#    • Task: metadata
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# metadata_simple_all_query   💡 LLM sugiere: metadata_simple_all_query
#    ⏱️  Tiempo de respuesta: 2.17s
#    ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [ERROR] content execution failed: ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 4.411s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: ¿De qué año es la película Inception?
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 4.411s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================

# %% [markdown]
# ### Test 5: Pregunta Ambigua (Top-K = 2)

# %%
# Pregunta ambigua que podría ir a múltiples grafos
question = "¿Cuánto cuesta?"

result = await process_question(question)
print_result(result, question)

# Debería mostrar:
# - Top-K = 2 (scores similares)
# - Posible re-routing si confidence < threshold
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
#   • Tipos de entidad: price
#   • Tokens: 2
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.9,
#   "talent": 0.1,
#   "content": 0.2,
#   "platform": 0.2,
#   "common": 0.1
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.9,\n  "talent": 0.1,\n  "content": 0.2,\n  "platform": 0.2,\n  "common": 0.1\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.9,\n  "talent": 0.1,\n  "content": 0.2,\n  "platform": 0.2,\n  "common": 0.1\n}
#
# [SCORES] Puntuación de candidatos:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   • content: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ business_graph (score: 0.90)
# [DEBUG] selected = [('business', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('business', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('business', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'business': 0.9, 'talent': 0.1, 'content': 0.1, 'platform': 0.2, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('business', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • business_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching business (score: 0.90)
#
# [BUSINESS_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [BUSINESS CLASSIFIER] Clasificando pregunta: ¿Cuánto cuesta?
# PRICING[BUSINESS CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'PRICING'}]}
# [BUSINESS CLASSIFIER] Task final: pricing
#
# ================================================================================
# [PRICING NODE]
# ================================================================================
# Question: ¿Cuánto cuesta?
# Current state:
#    • Task: pricing
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: build_presence_with_price_query, query_presence_with_price, tool_hits_with_quality, tool_prices_changes_last_n_days, tool_prices_history, tool_prices_latest, tool_prices_stats
# query_presence_with_price   💡 LLM sugiere: query_presence_with_price
#    ⏱️  Tiempo de respuesta: 1.26s
#    ✅ Tool válida, usando: query_presence_with_price
# [SUCCESS] Tool selected: query_presence_with_price
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Lo siento, pero su consulta es demasiado general. Para poder ayudarle con los precios, necesito que especifique:
# - ¿Qué producto o servicio de streaming desea consultar?
# - ¿En qué país está buscando el precio?
# - ¿Qué detalles adicionales me puede proporcionar? (plataforma, definición, etc.)
#
# Por ejemplo, podría preguntarme:
# - ¿Cuánto cuesta Netflix Premium en México?
# - ¿Cuál es el precio de HBO Max en calidad HD en Argentina?
#
# Cuanto más específico sea, mejor podré ayudarle a encontrar el precio exacto usando las herramientas disponibles.[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Lo siento, pero su consulta es demasiado general. Para poder ayudarle con los precios, necesito que especifique:\n- ¿Qué producto o servicio de streaming desea consultar?\n- ¿En qué país está buscando el precio?\n- ¿Qué detalles adicionales me puede proporcionar? (plataforma, definición, etc.)\n\nPor ejemplo, podría preguntarme:\n- ¿Cuánto cuesta Netflix Premium en México?\n- ¿Cuál es el precio de HBO Max en calidad HD en Argentina?\n\nCuanto más específico sea, mejor podré ayudarle a encontrar el precio exacto usando las herramientas disponibles.'}]}
#
# [SUCCESS] Pricing node completed
#    • Total tool calls: 1
#    • Total accumulated data: 660 characters
#    • Last node: pricing_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=pricing
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# [BUSINESS_GRAPH] Completed
#   • Status: not_applicable
#   • Confidence: 0.30
#   • Reason: Graph cannot handle this question
# [PARALLEL EXECUTOR] business completed:
#   • Status: not_applicable
#   • Confidence: 0.60 (routing: 0.90, subgraph: 0.30)
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 10.186s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. business_graph: status=not_applicable, confidence=0.60
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results not_applicable, needs rerouting
#
# ================================================================================
# 📝 PREGUNTA: ¿Cuánto cuesta?
# ================================================================================
#
# 💬 RESPUESTA:
#
#
# 🎯 ROUTER:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   ✅ Seleccionados: ['business(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: need_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 10.186s
#   • Hops: 1/2
#   • Visited: ['business']
#
# ================================================================================

# %% [markdown]
# ### Test 6: Pregunta con Nombre Ambiguo

# %%
# Pregunta con nombre que podría tener múltiples matches
question = "¿Qué películas ha hecho Nolan?"

result = await process_question(question)
print_result(result, question)

# Debería mostrar:
# - talent_graph con alta confianza
# - Posible ambiguous si hay múltiples "Nolan" (Christopher, Jonathan)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha hecho Nolan?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AR', 'BO', 'BR', 'CL', 'CO', 'CR', 'CU', 'DO', 'EC', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'PR', 'PY', 'SV', 'UY', 'VE']
#   • Tipos de entidad: movie
#   • Tokens: 5
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha hecho Nolan?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.9,
#   "content": 0.6,
#   "platform": 0.1,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   • platform: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ talent_graph (score: 0.90)
# [DEBUG] selected = [('talent', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('talent', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('talent', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'talent': 0.9, 'content': 0.3, 'business': 0.1, 'platform': 0.1, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('talent', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • talent_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching talent (score: 0.90)
#
# [TALENT GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha hecho Nolan?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha hecho Nolan?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.43s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Para responder a su pregunta, necesito usar el ID de director validado para Christopher Nolan. Sin embargo, no veo un ID de director en la solicitud. Puedo ayudarle si me proporciona el ID de director validado de Christopher Nolan.
#
# Sin el ID específico de director, no puedo realizar una búsqueda precisa de su filmografía. ¿Podría proporcionarme el ID de director validado para Christopher Nolan?[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Para responder a su pregunta, necesito usar el ID de director validado para Christopher Nolan. Sin embargo, no veo un ID de director en la solicitud. Puedo ayudarle si me proporciona el ID de director validado de Christopher Nolan.\n\nSin el ID específico de director, no puedo realizar una búsqueda precisa de su filmografía. ¿Podría proporcionarme el ID de director validado para Christopher Nolan?'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 508 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# [TALENT GRAPH] Completed
#   • Status: not_applicable
#   • Confidence: 0.30
#   • Needs reroute: True
#   • Reason: Graph cannot handle this question
# [PARALLEL EXECUTOR] talent completed:
#   • Status: not_applicable
#   • Confidence: 0.60 (routing: 0.90, subgraph: 0.30)
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 7.839s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=not_applicable, confidence=0.60
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results not_applicable, needs rerouting
#
# ================================================================================
# 📝 PREGUNTA: ¿Qué películas ha hecho Nolan?
# ================================================================================
#
# 💬 RESPUESTA:
#
#
# 🎯 ROUTER:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   ✅ Seleccionados: ['talent(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: need_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 7.839s
#   • Hops: 1/2
#   • Visited: ['talent']
#
# ================================================================================

# %% [markdown]
# ## 5. Test Personalizado
#
# Escribe tu propia pregunta aquí:

# %%
# 👇 Escribe tu pregunta aquí
question = "Tu pregunta aquí"

result = await process_question(question)
print_result(result, question)
# Out:
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: Tu pregunta aquí
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): N/A
#   • Tipos de entidad: N/A
#   • Tokens: 3
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: Tu pregunta aquí
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.3,
#   "talent": 0.7,
#   "content": 0.8,
#   "platform": 0.4,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.3,\n  "talent": 0.7,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.3,\n  "talent": 0.7,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: Tu pregunta aquí
# METADATA[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'METADATA'}]}
# [CLASSIFIER] Task final: metadata
#
# ================================================================================
# [METADATA NODE]
# ================================================================================
# Question: Tu pregunta aquí
# Current state:
#    • Task: metadata
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# metadata_simple_all_query   💡 LLM sugiere: metadata_simple_all_query
#    ⏱️  Tiempo de respuesta: 1.98s
#    ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [ERROR] content execution failed: ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.550s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: Tu pregunta aquí
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.8,
#   "talent": 0.7,
#   "content": 0.9,
#   "platform": 0.3,
#   "common": 0.1
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.8,\n  "talent": 0.7,\n  "content": 0.9,\n  "platform": 0.3,\n  "common": 0.1\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.8,\n  "talent": 0.7,\n  "content": 0.9,\n  "platform": 0.3,\n  "common": 0.1\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: Tu pregunta aquí
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: Tu pregunta aquí
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.60s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.236s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: Tu pregunta aquí
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.236s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================

# %% [markdown]
# ## 6. Análisis de Múltiples Preguntas

# %%
# Lista de preguntas para testear en batch
test_questions = [
    "¿Qué películas ha dirigido Steven Spielberg?",
    "¿Dónde puedo ver Breaking Bad?",
    "¿Cuánto cuesta Disney+ en México?",
    "¿De qué año es The Matrix?",
    "¿Qué plataformas tienen Game of Thrones?",
    "¿Quién actuó en Titanic?",
    "¿Cuál es la serie más popular?",
]

results = []

for i, q in enumerate(test_questions, 1):
    print(f"\n{'='*80}")
    print(f"TEST {i}/{len(test_questions)}")
    print(f"{'='*80}")
    
    try:
        result = await process_question(q)
        print_result(result, q)
        
        # Guardar para análisis
        results.append({
            "question": q,
            "winning_node": result.get("winning_node"),
            "confidence": result.get("final_confidence"),
            "decision": result.get("aggregator_decision"),
            "hops": result.get("rerouting_count", 0)
        })
    except Exception as e:
        print(f"❌ Error: {e}")
        results.append({
            "question": q,
            "error": str(e)
        })

print(f"\n\n{'='*80}")
print("📊 RESUMEN DE TESTS")
print(f"{'='*80}")
print(f"Total preguntas: {len(results)}")
print(f"\nResultados por nodo:")

from collections import Counter
node_counts = Counter([r.get("winning_node") for r in results if "winning_node" in r])
for node, count in node_counts.most_common():
    print(f"  • {node}: {count}")
# Out:
# ================================================================================
# TEST 1/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Steven Spielberg?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AR', 'BO', 'BR', 'CL', 'CO', 'CR', 'CU', 'DO', 'EC', 'GT', 'HN', 'MX', 'NI', 'PA', 'PE', 'PR', 'PY', 'SV', 'UY', 'VE']
#   • Tipos de entidad: movie
#   • Tokens: 6
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Qué películas ha dirigido Steven Spielberg?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.9,
#   "content": 0.6,
#   "platform": 0.1,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.9,\n  "content": 0.6,\n  "platform": 0.1,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   • platform: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ talent_graph (score: 0.90)
# [DEBUG] selected = [('talent', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('talent', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('talent', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'talent': 0.9, 'content': 0.3, 'business': 0.1, 'platform': 0.1, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('talent', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • talent_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching talent (score: 0.90)
#
# [TALENT GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [TALENT CLASSIFIER] Clasificando pregunta: ¿Qué películas ha dirigido Steven Spielberg?
# DIRECTORS[TALENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DIRECTORS'}]}
# [TALENT CLASSIFIER] Task final: directors
#
# ================================================================================
# [DIRECTORS NODE]
# ================================================================================
# Question: ¿Qué películas ha dirigido Steven Spielberg?
# Current state:
#    • Task: directors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_director_collaborators, get_director_filmography
# get_director_filmography   💡 LLM sugiere: get_director_filmography
#    ⏱️  Tiempo de respuesta: 1.24s
#    ✅ Tool válida, usando: get_director_filmography
# [SUCCESS] Tool selected: get_director_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Entiendo que desea conocer la filmografía de Steven Spielberg. Utilizaré la herramienta de búsqueda de filmografía con el ID de director validado.
# Tool #1: get_director_filmography
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📝 Operación: director_filmography_619
# 📄 Query:
#
#     SELECT DISTINCT
#         m.uid,
#         m.title,
#         m.type,
#         m.year,
#         m.imdb_id
#     FROM ms.metadata_simple_all m
#     INNER JOIN ms.directed_by dt ON m.uid = dt.uid
#     WHERE dt.director_id = %s
#     ORDER BY m.year DESC NULLS LAST, m.title
#     LIMIT %s
#
# 🔧 Parámetros: (619, 10)
# ================================================================================
#
# ✅ Query retornó 0 filas en 0.322s
#
# Me disculpo, pero parece que ha habido un problema al recuperar la filmografía del director. Sin embargo, conozco la trayectoria de Steven Spielberg y puedo compartir algunos detalles sobre sus películas más famosas:
#
# Algunas de las películas más destacadas que ha dirigido Steven Spielberg incluyen:
#
# 1. Tiburón (1975)
# 2. Close Encounters of the Third Kind (1977)
# 3. Raiders of the Lost Ark (1981)
# 4. E.T. el Extraterrestre (1982)
# 5. La Lista de Schindler (1993)
# 6. Salvar al Soldado Ryan (1998)
# 7. Minority Report (2002)
# 8. Munich (2005)
# 9. Lincoln (2012)
# 10. Bridge of Spies (2015)
# 11. The Post (2017)
# 12. West Side Story (2021)
#
# Spielberg es conocido por su capacidad para dirigir en diversos géneros, desde ciencia ficción hasta dramas históricos, y ha ganado múltiples premios Oscar por su trabajo.
#
# Si desea información más precisa o actualizada sobre su filmografía completa, le recomendaría consultar fuentes especializadas en cine.[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Me disculpo, pero parece que ha habido un problema al recuperar la filmografía del director. Sin embargo, conozco la trayectoria de Steven Spielberg y puedo compartir algunos detalles sobre sus películas más famosas:\n\nAlgunas de las películas más destacadas que ha dirigido Steven Spielberg incluyen:\n\n1. Tiburón (1975)\n2. Close Encounters of the Third Kind (1977)\n3. Raiders of the Lost Ark (1981)\n4. E.T. el Extraterrestre (1982)\n5. La Lista de Schindler (1993)\n6. Salvar al Soldado Ryan (1998)\n7. Minority Report (2002)\n8. Munich (2005)\n9. Lincoln (2012)\n10. Bridge of Spies (2015)\n11. The Post (2017)\n12. West Side Story (2021)\n\nSpielberg es conocido por su capacidad para dirigir en diversos géneros, desde ciencia ficción hasta dramas históricos, y ha ganado múltiples premios Oscar por su trabajo.\n\nSi desea información más precisa o actualizada sobre su filmografía completa, le recomendaría consultar fuentes especializadas en cine.'}]}
#
# [SUCCESS] Directors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 1068 characters
#    • Last node: directors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=directors
# COMPLETO[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'COMPLETO'}]}
# [SUPERVISOR] ✓ Pregunta respondida, ir a format
# Algunas de las películas más destacadas que ha dirigido Steven Spielberg incluyen:
#
# 1. Tiburón (1975)
# 2. Close Encounters of the Third Kind (1977)
# 3. Raiders of the Lost Ark (1981)
# 4. E.T. el Extraterrestre (1982)
# 5. La Lista de Schindler (1993)
# 6. Salvar al Soldado Ryan (1998)
# 7. Minority Report (2002)
# 8. Munich (2005)
# 9. Lincoln (2012)
# 10. Bridge of Spies (2015)
# 11. The Post (2017)
# 12. West Side Story (2021)[TALENT GRAPH] Completed
#   • Status: resolved
#   • Confidence: 0.95
#   • Needs reroute: False
# [PARALLEL EXECUTOR] talent completed:
#   • Status: resolved
#   • Confidence: 0.93 (routing: 0.90, subgraph: 0.95)
# [STOP_AFTER] talent resolved with 0.93 >= 0.85
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 16.872s
# [PARALLEL EXECUTOR] ⚡ Cancelled: STOP_AFTER triggered by talent
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=resolved, confidence=0.93
# [AGGREGATOR] Decision: winner
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] ✅ Winner: unknown
# [AGGREGATOR]    Confidence: 0.925 >= 0.650
# [AGGREGATOR]    Latency: 0.000s
#
# ================================================================================
# 📝 PREGUNTA: ¿Qué películas ha dirigido Steven Spielberg?
# ================================================================================
#
# 💬 RESPUESTA:
# {'role': 'assistant', 'content': [{'text': 'Algunas de las películas más destacadas que ha dirigido Steven Spielberg incluyen:\n\n1. Tiburón (1975)\n2. Close Encounters of the Third Kind (1977) \n3. Raiders of the Lost Ark (1981)\n4. E.T. el Extraterrestre (1982)\n5. La Lista de Schindler (1993)\n6. Salvar al Soldado Ryan (1998)\n7. Minority Report (2002)\n8. Munich (2005)\n9. Lincoln (2012)\n10. Bridge of Spies (2015)\n11. The Post (2017)\n12. West Side Story (2021)'}]}
#
# 🎯 ROUTER:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   ✅ Seleccionados: ['talent(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: winner
#   • Ganador: unknown
#   • Confidence: 0.925 >= 0.650
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 16.872s
#   • Latencia aggregator: 0.000s
#   • Hops: 0/2
#   • Visited: ['talent']
#
# ================================================================================
#
# ================================================================================
# TEST 2/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Breaking Bad?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
#   • Tipos de entidad: country
#   • Tokens: 5
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Breaking Bad?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.1,
#   "content": 0.3,
#   "platform": 0.8,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.3,\n  "platform": 0.8,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.3,\n  "platform": 0.8,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Dónde puedo ver Breaking Bad?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Dónde puedo ver Breaking Bad?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.08s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 2.817s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Dónde puedo ver Breaking Bad?
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.3,
#   "content": 0.5,
#   "platform": 0.8,
#   "common": 0.1
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.3,\n  "content": 0.5,\n  "platform": 0.8,\n  "common": 0.1\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.3,\n  "content": 0.5,\n  "platform": 0.8,\n  "common": 0.1\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Dónde puedo ver Breaking Bad?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Dónde puedo ver Breaking Bad?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.42s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.261s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: ¿Dónde puedo ver Breaking Bad?
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.261s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================
#
# ================================================================================
# TEST 3/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta Disney+ en México?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AT', 'BE', 'BG', 'CY', 'CZ', 'DE', 'DK', 'EE', 'ES', 'FI', 'FR', 'GR', 'HR', 'HU', 'IE', 'IT', 'LT', 'LU', 'LV', 'MT', 'NL', 'PL', 'PT', 'RO', 'SE', 'SI', 'SK']
#   • Tipos de entidad: price, platform
#   • Tokens: 5
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Cuánto cuesta Disney+ en México?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.8,
#   "talent": 0.0,
#   "content": 0.0,
#   "platform": 0.9,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.8,\n  "talent": 0.0,\n  "content": 0.0, \n  "platform": 0.9,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.8,\n  "talent": 0.0,\n  "content": 0.0, \n  "platform": 0.9,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   • content: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ business_graph (score: 0.90)
# [DEBUG] selected = [('business', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('business', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('business', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'business': 0.9, 'talent': 0.1, 'content': 0.1, 'platform': 0.2, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('business', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • business_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching business (score: 0.90)
#
# [BUSINESS_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [BUSINESS CLASSIFIER] Clasificando pregunta: ¿Cuánto cuesta Disney+ en México?
# PRICING[BUSINESS CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'PRICING'}]}
# [BUSINESS CLASSIFIER] Task final: pricing
#
# ================================================================================
# [PRICING NODE]
# ================================================================================
# Question: ¿Cuánto cuesta Disney+ en México?
# Current state:
#    • Task: pricing
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: build_presence_with_price_query, query_presence_with_price, tool_hits_with_quality, tool_prices_changes_last_n_days, tool_prices_history, tool_prices_latest, tool_prices_stats
# query_presence_with_price   💡 LLM sugiere: query_presence_with_price
#    ⏱️  Tiempo de respuesta: 1.49s
#    ✅ Tool válida, usando: query_presence_with_price
# [SUCCESS] Tool selected: query_presence_with_price
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
#
# Tool #1: query_presence_with_price
# I apologize for the error. Let me try again with a slightly different format:
# Tool #2: query_presence_with_price
# I'll make one more attempt with a direct approach:
# Tool #3: query_presence_with_price
# I apologize, but I'm experiencing technical difficulties retrieving the price for Disney+ in Mexico. The tool is not responding as expected. Without being able to provide concrete data from the pricing tool, I cannot confidently state the current price of Disney+ in Mexico.[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': "I apologize, but I'm experiencing technical difficulties retrieving the price for Disney+ in Mexico. The tool is not responding as expected. Without being able to provide concrete data from the pricing tool, I cannot confidently state the current price of Disney+ in Mexico."}]}
#
# [SUCCESS] Pricing node completed
#    • Total tool calls: 1
#    • Total accumulated data: 381 characters
#    • Last node: pricing_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=pricing
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# [BUSINESS_GRAPH] Completed
#   • Status: not_applicable
#   • Confidence: 0.30
#   • Reason: Graph cannot handle this question
# [PARALLEL EXECUTOR] business completed:
#   • Status: not_applicable
#   • Confidence: 0.60 (routing: 0.90, subgraph: 0.30)
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 13.108s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. business_graph: status=not_applicable, confidence=0.60
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results not_applicable, needs rerouting
#
# ================================================================================
# 📝 PREGUNTA: ¿Cuánto cuesta Disney+ en México?
# ================================================================================
#
# 💬 RESPUESTA:
#
#
# 🎯 ROUTER:
#   • business: 0.90
#   • platform: 0.20
#   • talent: 0.10
#   ✅ Seleccionados: ['business(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: need_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 13.108s
#   • Hops: 1/2
#   • Visited: ['business']
#
# ================================================================================
#
# ================================================================================
# TEST 4/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿De qué año es The Matrix?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): N/A
#   • Tipos de entidad: N/A
#   • Tokens: 6
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿De qué año es The Matrix?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.3,
#   "content": 0.9,
#   "platform": 0.2,
#   "common": 0.0
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.3,\n  "content": 0.9,\n  "platform": 0.2,\n  "common": 0.0\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.3,\n  "content": 0.9,\n  "platform": 0.2,\n  "common": 0.0\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿De qué año es The Matrix?
# METADATA[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'METADATA'}]}
# [CLASSIFIER] Task final: metadata
#
# ================================================================================
# [METADATA NODE]
# ================================================================================
# Question: ¿De qué año es The Matrix?
# Current state:
#    • Task: metadata
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# metadata_simple_all_stats   💡 LLM sugiere: metadata_simple_all_stats
#    ⏱️  Tiempo de respuesta: 1.46s
#    ❌ Tool inválida: 'metadata_simple_all_stats'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [ERROR] content execution failed: ❌ Tool inválida: 'metadata_simple_all_stats'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 2.870s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿De qué año es The Matrix?
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.2,
#   "content": 0.9,
#   "platform": 0.2,
#   "common": 0.2
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.2,\n  "content": 0.9,\n  "platform": 0.2,\n  "common": 0.2\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.2,\n  "content": 0.9,\n  "platform": 0.2,\n  "common": 0.2\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿De qué año es The Matrix?
# METADATA[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'METADATA'}]}
# [CLASSIFIER] Task final: metadata
#
# ================================================================================
# [METADATA NODE]
# ================================================================================
# Question: ¿De qué año es The Matrix?
# Current state:
#    • Task: metadata
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# metadata_simple_all_query   💡 LLM sugiere: metadata_simple_all_query
#    ⏱️  Tiempo de respuesta: 1.43s
#    ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [ERROR] content execution failed: ❌ Tool inválida: 'metadata_simple_all_query'. Tools válidas: simple_all_count, simple_all_list, simple_all_query, simple_all_stats
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.316s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: ¿De qué año es The Matrix?
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.316s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================
#
# ================================================================================
# TEST 5/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Qué plataformas tienen Game of Thrones?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['DK', 'EE', 'FI', 'FO', 'GB', 'GL', 'IE', 'IM', 'LT', 'LV', 'NO', 'SE']
#   • Tipos de entidad: platform
#   • Tokens: 6
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Qué plataformas tienen Game of Thrones?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.2,
#   "talent": 0.1,
#   "content": 0.4,
#   "platform": 0.9,
#   "common": 0.2
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.4,\n  "platform": 0.9,\n  "common": 0.2\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.2,\n  "talent": 0.1,\n  "content": 0.4,\n  "platform": 0.9,\n  "common": 0.2\n}
#
# [SCORES] Puntuación de candidatos:
#   • platform: 0.90
#   • content: 0.30
#   • business: 0.20
#   • talent: 0.10
#   • common: 0.05
#
# [ROUTER] Top-K = 1 (solo 1 candidato disponible)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ platform_graph (score: 0.90)
# [DEBUG] selected = [('platform', 0.9)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('platform', 0.9), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('platform', 0.9)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'platform': 0.9, 'business': 0.2, 'talent': 0.1, 'content': 0.3, 'common': 0.05}
# [DEBUG] selected_candidates from state: [('platform', 0.9)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • platform_graph (score: 0.90)
# [PARALLEL EXECUTOR] Launching platform (score: 0.90)
#
# [PLATFORM_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CLASSIFIER] Clasificando pregunta: ¿Qué plataformas tienen Game of Thrones?
# PRESENCE[CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'PRESENCE'}]}
# [CLASSIFIER] Task final: presence
#
# ================================================================================
# [PRESENCE NODE]
# ================================================================================
# Question: ¿Qué plataformas tienen Game of Thrones?
# Current state:
#    • Task: presence
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: country_platform_summary, platform_count_by_country, presence_count, presence_list, presence_statistics
# presence_list   💡 LLM sugiere: presence_list
#    ⏱️  Tiempo de respuesta: 1.35s
#    ✅ Tool válida, usando: presence_list
# [SUCCESS] Tool selected: presence_list
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Voy a buscar la presencia de "Game of Thrones" en diferentes plataformas:
# Tool #1: presence_list
#
# ================================================================================
# 🔍 SQL QUERY EJECUTADA
# ================================================================================
# 📄 Query:
#
#     SELECT p.clean_title, p.uid, p.hash_unique, p.platform_name, p.platform_code, p.iso_alpha2, p.type, p.is_kids, p.is_exclusive, p.plan_name, p.out_on, p.duration, p.permalink
#     FROM ms.new_cp_presence p
#     WHERE p.out_on IS NULL AND p.clean_title ILIKE %(title_like)s
#     ORDER BY p.clean_title ASC, p.hash_unique
#     LIMIT %(limit)s OFFSET %(offset)s;
#
# 🔧 Parámetros: {'title_like': '%Game of Thrones%', 'limit': 20, 'offset': 0}
# ================================================================================
#
# ✅ Query retornó 20 filas en 30.335s
#
# Basado en los resultados, las plataformas que tienen "Game of Thrones" son:
#
# 1. Max (HBO Max) - en Perú
# 2. YouTube Premium - en Estados Unidos
# 3. Xfinity Stream - en Estados Unidos
# 4. Tubi - en Canadá y Estados Unidos
# 5. ARD Mediathek - en Alemania (principalmente contenido relacionado)
# 6. FOX Sports - en Estados Unidos (contenido relacionado)
# 7. Ran - en Alemania (contenido relacionado)
#
# Nota: Algunas de estas entradas son videos sobre Game of Thrones o relacionados, no necesariamente la serie completa. Las plataformas principales para ver la serie completa parecen ser Max (HBO), YouTube Premium y Xfinity Stream.
#
# ¿Te gustaría que profundice en alguna plataforma en particular o en algún país específico?[DATA] Obtained: 2 characters
# ...
# [TALENT CLASSIFIER] Task final: actors
#
# ================================================================================
# [ACTORS NODE]
# ================================================================================
# Question: ¿Quién actuó en Titanic?
# Current state:
#    • Task: actors
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: get_actor_coactors, get_actor_coactors_by_name, get_actor_filmography
# get_actor_filmography   💡 LLM sugiere: get_actor_filmography
#    ⏱️  Tiempo de respuesta: 1.53s
#    ✅ Tool válida, usando: get_actor_filmography
# [SUCCESS] Tool selected: get_actor_filmography
# [AGENT] Executing tool with model: us.anthropic.claude-3-5-haiku-20241022-v1:0...
# Lo siento, pero no puedo responder directamente a su pregunta porque no tengo un actor_id validado para realizar la búsqueda. Para poder usar la herramienta de filmografía, necesito que me proporcione el ID validado de alguno de los actores de Titanic.
#
# Si desea conocer los actores de Titanic, podría ayudarle mejor si me indica específicamente de qué actor quiere saber la información, por ejemplo, Leonardo DiCaprio, Kate Winslet u otro actor principal. Una vez me proporcione el actor_id validado, podré buscar su filmografía y verificar su participación en la película.
#
# ¿Podría proporcionarme el actor_id validado de alguno de los actores de Titanic?[DATA] Obtained: 2 characters
# [DATA] {'role': 'assistant', 'content': [{'text': 'Lo siento, pero no puedo responder directamente a su pregunta porque no tengo un actor_id validado para realizar la búsqueda. Para poder usar la herramienta de filmografía, necesito que me proporcione el ID validado de alguno de los actores de Titanic.\n\nSi desea conocer los actores de Titanic, podría ayudarle mejor si me indica específicamente de qué actor quiere saber la información, por ejemplo, Leonardo DiCaprio, Kate Winslet u otro actor principal. Una vez me proporcione el actor_id validado, podré buscar su filmografía y verificar su participación en la película.\n\n¿Podría proporcionarme el actor_id validado de alguno de los actores de Titanic?'}]}
#
# [SUCCESS] Actors node completed
#    • Total tool calls: 1
#    • Total accumulated data: 762 characters
#    • Last node: actors_node
# ================================================================================
#
# [SUPERVISOR] Evaluando estado... tools=1, task=actors
# CONTINUAR[SUPERVISOR] Decision del LLM: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'CONTINUAR'}]}
# [SUPERVISOR] ✗ Necesita mas informacion, volviendo al main router
# [TALENT GRAPH] Completed
#   • Status: not_applicable
#   • Confidence: 0.30
#   • Needs reroute: True
#   • Reason: Graph cannot handle this question
# [PARALLEL EXECUTOR] talent completed:
#   • Status: not_applicable
#   • Confidence: 0.60 (routing: 0.90, subgraph: 0.30)
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 9.344s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=not_applicable, confidence=0.60
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results not_applicable, needs rerouting
#
# ================================================================================
# 📝 PREGUNTA: ¿Quién actuó en Titanic?
# ================================================================================
#
# 💬 RESPUESTA:
#
#
# 🎯 ROUTER:
#   • talent: 0.90
#   • content: 0.30
#   • business: 0.10
#   ✅ Seleccionados: ['talent(0.90)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: need_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 9.344s
#   • Hops: 1/2
#   • Visited: ['talent']
#
# ================================================================================
#
# ================================================================================
# TEST 7/7
# ================================================================================
#
# ================================================================================
# 🔍 LIGHTWEIGHT PREPROCESSOR - Normalización Barata
# ================================================================================
# 📝 Pregunta: ¿Cuál es la serie más popular?
#
# [PREPROCESSING] Contexto extraído:
#   • País (ISO-2): ['AD', 'AL', 'BA', 'CY', 'ES', 'GI', 'GR', 'HR', 'IT', 'ME', 'MK', 'MT', 'PT', 'RS', 'SI', 'SM', 'VA', 'XK']
#   • Tipos de entidad: series
#   • Tokens: 6
# ================================================================================
#
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Cuál es la serie más popular?
# [ROUTER] Visited: set(), Hops: 0/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.7,
#   "talent": 0.5,
#   "content": 0.8,
#   "platform": 0.4,
#   "common": 0.3
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.7,\n  "talent": 0.5,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.3\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.7,\n  "talent": 0.5,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.3\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'aggregator_decision', 'needs_clarification', 'clarification_reason']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Cuál es la serie más popular?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Cuál es la serie más popular?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.43s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.662s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 0/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 0/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 0/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 0/2), marking for router
#
# ================================================================================
# 🎯 UNIFIED ROUTER - Puntuación de Candidatos
# ================================================================================
# 📝 Pregunta: ¿Cuál es la serie más popular?
# [ROUTER] Visited: set(), Hops: 1/2
# [ROUTER] 🤖 Puntuando candidatos con LLM...
# {
#   "business": 0.7,
#   "talent": 0.3,
#   "content": 0.8,
#   "platform": 0.4,
#   "common": 0.2
# }{'role': 'assistant', 'content': [{'text': '{\n  "business": 0.7,\n  "talent": 0.3,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.2\n}'}]}
# [ERROR] JSON inválido: Expecting property name enclosed in double quotes: line 1 column 2 (char 1)
# [DEBUG] JSON extraído: {\n  "business": 0.7,\n  "talent": 0.3,\n  "content": 0.8,\n  "platform": 0.4,\n  "common": 0.2\n}
#
# [SCORES] Puntuación de candidatos:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   • platform: 0.20
#   • common: 0.10
#
# [ROUTER] Top-K = 1 (diff=0.20 > 0.10)
#
# [SELECTED] Candidatos seleccionados: 1
#   ✅ content_graph (score: 0.60)
# [DEBUG] selected = [('content', 0.6)]
# [DEBUG] type(selected) = <class 'list'>
# [DEBUG] selected[0] = ('content', 0.6), type = <class 'tuple'>
# [DEBUG] Returning state with keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] selected_candidates in return: [('content', 0.6)]
#
# ================================================================================
# [PARALLEL EXECUTOR] Con presupuesto y timeout
# ================================================================================
# [CONFIG] TOOL_TIMEOUT=2.0s, BUDGET=6, STOP_AFTER=0.85
# [DEBUG] state keys: ['question', 'answer', 'selected_graph', 'routing_done', 'error', 'needs_rerouting', 'previous_graph', 'rerouting_count', 'validation_done', 'validated_entities', 'needs_validation', 'needs_user_input', 'validation_message', 'preprocessing_done', 'lightweight_context', 'needs_heavy_validation', 'routing_scores', 'selected_candidates', 'visited_graphs', 'parallel_results', 'parallel_candidates', 'tools_used', 'budget_exhausted', 'cancelled_branch', 'lat_parallel', 'lat_aggregator', 'aggregator_decision', 'needs_clarification', 'clarification_reason', 'clarification_context', 'clarification_context_updated']
# [DEBUG] routing_done: True
# [DEBUG] routing_scores: {'content': 0.6, 'talent': 0.4, 'business': 0.2, 'platform': 0.2, 'common': 0.1}
# [DEBUG] selected_candidates from state: [('content', 0.6)]
# [DEBUG] type: <class 'list'>
# [PARALLEL EXECUTOR] Executing 1 candidate(s):
#   • content_graph (score: 0.60)
# [PARALLEL EXECUTOR] Launching content (score: 0.60)
#
# [CONTENT_GRAPH] Starting execution...
# [SUPERVISOR] Evaluando estado... tools=0, task=None
# [SUPERVISOR] Primera iteracion, necesita clasificacion
# [CONTENT CLASSIFIER] Clasificando pregunta: ¿Cuál es la serie más popular?
# DISCOVERY[CONTENT CLASSIFIER] Decision: {'ROLE': 'ASSISTANT', 'CONTENT': [{'TEXT': 'DISCOVERY'}]}
# [CLASSIFIER] Task final: discovery
#
# ================================================================================
# [DISCOVERY NODE]
# ================================================================================
# Question: ¿Cuál es la serie más popular?
# Current state:
#    • Task: discovery
#    • Previous tool calls: 0
#    • Accumulated data: 0 characters
#
# [ROUTING] Selecting tool...
#    🔍 Router LLM analizando pregunta...
#    📋 Tools disponibles: filmography_by_uid, multiple_titles_info, title_rating
# get_title_rating   💡 LLM sugiere: get_title_rating
#    ⏱️  Tiempo de respuesta: 1.32s
#    ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [ERROR] content execution failed: ❌ Tool inválida: 'get_title_rating'. Tools válidas: filmography_by_uid, multiple_titles_info, title_rating
# [PARALLEL EXECUTOR] Completed: 1 valid results
# [PARALLEL EXECUTOR] Tools used: 1/6
# [PARALLEL EXECUTOR] Latency: 3.117s
#
# ================================================================================
# [AGGREGATOR] ÚNICO JUEZ - Evaluating parallel results
# ================================================================================
# [AGGREGATOR] Evaluating 1 results
#   1. unknown: status=error, confidence=0.00
# [AGGREGATOR] Decision: all_low
# [AGGREGATOR] Hops: 1/2
# [AGGREGATOR] All results below threshold
# [AGGREGATOR]    Hops: 1/2
# [AGGREGATOR] 🔄 Re-routing (hops < MAX_HOPS)
#
# ================================================================================
# [CLARIFIER] LOOP-SAFE - Generating clarification
# ================================================================================
# [CLARIFIER] Reason: all_low_confidence
# [CLARIFIER] Hops: 1/2
# [CLARIFIER] Loop-safe: True
# [CLARIFIER] Generated message (201 chars)
# [CLARIFIER] Can re-route (hops: 1/2), marking for router
#
# ================================================================================
# 📝 PREGUNTA: ¿Cuál es la serie más popular?
# ================================================================================
#
# 💬 RESPUESTA:
# No pude entender tu pregunta con suficiente confianza.
#
# ¿Podrías proporcionar 1-2 detalles adicionales?
#
# Ejemplos:
# • "¿Cuánto cuesta Netflix en Argentina?"
# • "¿Qué películas dirigió Christopher Nolan?"
#
# 🎯 ROUTER:
#   • content: 0.60
#   • talent: 0.40
#   • business: 0.20
#   ✅ Seleccionados: ['content(0.60)']
#
# ⚖️ AGGREGATOR:
#   • Decisión: all_low_reroute
#
# 📊 TELEMETRÍA:
#   • Tools usados: 1/6
#   • Budget agotado: False
#   • Latencia parallel: 3.117s
#   • Latencia aggregator: 0.000s
#   • Hops: 2/2
#
# ❓ CLARIFICACIÓN:
#   • Razón: all_low_confidence
#
# ================================================================================
#
#
# ================================================================================
# 📊 RESUMEN DE TESTS
# ================================================================================
# Total preguntas: 7
#
# Resultados por nodo:
#   • None: 5
#   • unknown: 1
#   • platform_graph: 1

# %% [markdown]
# ## 7. Exportar Resultados

# %%
# Exportar resultados a JSON
output_file = f"test_results_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"

with open(output_file, 'w', encoding='utf-8') as f:
    json.dump(results, f, indent=2, ensure_ascii=False)

print(f"✅ Resultados exportados a: {output_file}")
# Out:
# ✅ Resultados exportados a: test_results_20251014_235426.json

# %% [markdown]
# ## 8. Verificación de Reglas Determinísticas

# %%
# Verificar que las reglas se cumplen
print("🔍 VERIFICACIÓN DE REGLAS DETERMINÍSTICAS")
print("="*80)

# 1. Umbrales
print("\n1. Umbrales por nodo:")
for node, threshold in THRESHOLD_BY_NODE.items():
    if threshold is not None:
        print(f"  ✅ {node}: {threshold}")
    else:
        print(f"  🚫 {node}: None (nunca ganador)")

# 2. Presupuesto
print(f"\n2. Presupuesto y Timeout:")
print(f"  ✅ TOOL_TIMEOUT: {TOOL_TIMEOUT}s")
print(f"  ✅ BUDGET_TOOLS_PER_TURN: {BUDGET_TOOLS_PER_TURN}")
print(f"  ✅ STOP_AFTER: {STOP_AFTER}")

# 3. Loop-safe
print(f"\n3. Loop-safe:")
print(f"  ✅ MAX_HOPS: {MAX_HOPS}")
print(f"  ✅ MAX_CLARIFICATION_FIELDS: 2")

# 4. Análisis de resultados
if results:
    print(f"\n4. Análisis de resultados:")
    
    # Verificar que ningún common_graph ganó
    common_wins = [r for r in results if r.get("winning_node") == "common_graph"]
    if not common_wins:
        print(f"  ✅ common_graph nunca ganador (0/{len(results)})")
    else:
        print(f"  ❌ common_graph ganó {len(common_wins)} veces (ERROR)")
    
    # Verificar hops
    max_hops_used = max([r.get("hops", 0) for r in results])
    if max_hops_used <= MAX_HOPS:
        print(f"  ✅ Max hops respetado: {max_hops_used}/{MAX_HOPS}")
    else:
        print(f"  ❌ Max hops excedido: {max_hops_used} > {MAX_HOPS}")
    
    # Verificar confidence vs threshold
    threshold_violations = 0
    for r in results:
        node = r.get("winning_node")
        conf = r.get("confidence")
        if node and conf:
            threshold = THRESHOLD_BY_NODE.get(node, 0.65)
            if conf < threshold:
                threshold_violations += 1
    
    if threshold_violations == 0:
        print(f"  ✅ Todos los ganadores cumplen threshold (0 violaciones)")
    else:
        print(f"  ❌ {threshold_violations} ganadores no cumplen threshold")

print("\n" + "="*80)
# Out:
# 🔍 VERIFICACIÓN DE REGLAS DETERMINÍSTICAS
# ================================================================================
#
# 1. Umbrales por nodo:
#   ✅ platform_graph: 0.7
#   ✅ business_graph: 0.7
#   ✅ talent_graph: 0.75
#   ✅ content_graph: 0.68
#   🚫 common_graph: None (nunca ganador)
#
# 2. Presupuesto y Timeout:
#   ✅ TOOL_TIMEOUT: 2.0s
#   ✅ BUDGET_TOOLS_PER_TURN: 6
#   ✅ STOP_AFTER: 0.85
#
# 3. Loop-safe:
#   ✅ MAX_HOPS: 2
#   ✅ MAX_CLARIFICATION_FIELDS: 2
#
# 4. Análisis de resultados:
#   ✅ common_graph nunca ganador (0/7)
#   ✅ Max hops respetado: 2/2
#   ✅ Todos los ganadores cumplen threshold (0 violaciones)
#
# ================================================================================

# %% [markdown]
# ## 9. Notas y Observaciones
#
# Usa esta celda para agregar notas sobre los tests:

# %% [markdown]
# ### 📝 Observaciones:
#
# - [ ] Top-K dinámico funciona correctamente
# - [ ] STOP_AFTER cancela branches cuando corresponde
# - [ ] Umbrales calibrados son apropiados
# - [ ] Clarifier es loop-safe
# - [ ] Presupuesto se respeta
#
# ### 🐛 Issues encontrados:
#
# 1. ...
# 2. ...
#
# ### 💡 Mejoras sugeridas:
#
# 1. ...
# 2. ...
